# %%
import pygame
import random
import cv2
import numpy as np
import os
import datetime

# 初始化pygame
pygame.init()

# 设置屏幕大小
WIDTH, HEIGHT = 800, 600
screen = pygame.Surface((WIDTH, HEIGHT))  # 创建一个Surface来代替显示窗口

# 定义颜色
BLACK = (0, 0, 0)
WHITE = (255, 255, 255)

# 光点列表
points = []
# 不规则光圈列表
irregular_circles = []
# 星云列表
nebulae = []

# 创建初始光点
num_points = 300  # 增加光点数量
for _ in range(num_points):
    z = random.randint(HEIGHT, HEIGHT * 10)
    x = random.randint(0, WIDTH)
    y = random.randint(0, HEIGHT)
    size = random.randint(1, 3)
    speed_z = random.uniform(20, 40)  # 增加光点速度
    color = (random.randint(0, 255), random.randint(0, 255), random.randint(0, 255))  # 随机颜色
    points.append([x, y, z, size, speed_z, color])

# 创建初始不规则光圈
num_circles = 10  # 减少不规则光圈数量以提高性能
for _ in range(num_circles):
    x = random.randint(0, WIDTH)
    y = random.randint(0, HEIGHT)
    radius = random.randint(50, 200)
    speed_x = random.uniform(-1, 1)
    speed_y = random.uniform(-1, 1)
    color = (random.randint(0, 255), random.randint(0, 255), random.randint(0, 255), random.randint(50, 150))  # 随机颜色和透明度
    irregular_circles.append([x, y, radius, speed_x, speed_y, color])

# 创建初始星云
num_nebulae = 5  # 减少星云数量以提高性能
for _ in range(num_nebulae):
    x = random.randint(0, WIDTH)
    y = random.randint(0, HEIGHT)
    radius = random.randint(100, 300)
    speed_x = random.uniform(-0.5, 0.5)
    speed_y = random.uniform(-0.5, 0.5)
    color = (random.randint(0, 255), random.randint(0, 255), random.randint(0, 255), random.randint(30, 100))  # 随机颜色和透明度
    nebulae.append([x, y, radius, speed_x, speed_y, color])

# 设置视频保存路径和帧率
video_fps = 30
output_dir = "output_video"
os.makedirs(output_dir, exist_ok=True)
video_name = f"{output_dir}/cosmic_simulation_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}.mp4"

# 初始化视频写入器
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
video_writer = cv2.VideoWriter(video_name, fourcc, video_fps, (WIDTH, HEIGHT))

# 主循环
num_frames = video_fps * 15  # 15秒视频
for frame in range(num_frames):
    # 清屏
    screen.fill(BLACK)

    # 更新和绘制不规则光圈
    for circle in irregular_circles:
        # 更新位置
        circle[0] += circle[3]
        circle[1] += circle[4]

        # 如果超出边界，重新放置到另一侧
        if circle[0] < 0:
            circle[0] = WIDTH
        elif circle[0] > WIDTH:
            circle[0] = 0
        if circle[1] < 0:
            circle[1] = HEIGHT
        elif circle[1] > HEIGHT:
            circle[1] = 0

        # 绘制不规则光圈
        surf = pygame.Surface((WIDTH, HEIGHT), pygame.SRCALPHA)
        pygame.draw.circle(surf, circle[5], (int(circle[0]), int(circle[1])), circle[2])
        screen.blit(surf, (0, 0))

    # 更新和绘制星云
    for nebula in nebulae:
        # 更新位置
        nebula[0] += nebula[3]
        nebula[1] += nebula[4]

        # 如果超出边界，重新放置到另一侧
        if nebula[0] < 0:
            nebula[0] = WIDTH
        elif nebula[0] > WIDTH:
            nebula[0] = 0
        if nebula[1] < 0:
            nebula[1] = HEIGHT
        elif nebula[1] > HEIGHT:
            nebula[1] = 0

        # 绘制星云
        surf = pygame.Surface((WIDTH, HEIGHT), pygame.SRCALPHA)
        for _ in range(200):
            nebula_x = nebula[0] + random.uniform(-nebula[2], nebula[2])
            nebula_y = nebula[1] + random.uniform(-nebula[2], nebula[2])
            if random.random() < 0.3:  # 30%的概率绘制小点
                pygame.draw.circle(surf, nebula[5], (int(nebula_x), int(nebula_y)), 1)
        screen.blit(surf, (0, 0))

    # 更新和绘制光点
    for point in points:
        # 光点向观众飞来
        point[2] -= point[4]

        # 如果光点飞出屏幕，重新放置到远处
        if point[2] < 1:
            point[2] = random.randint(HEIGHT * 2, HEIGHT * 10)
            point[0] = random.randint(0, WIDTH)
            point[1] = random.randint(0, HEIGHT)

        # 计算视角效果
        perspective_size = int(point[3] * HEIGHT / point[2])
        perspective_x = point[0] + point[0] * (HEIGHT / point[2])
        perspective_y = point[1] + point[1] * (HEIGHT / point[2])

        # 确保光点在屏幕范围内
        if 0 <= perspective_x < WIDTH and 0 <= perspective_y < HEIGHT and perspective_size > 0:
            pygame.draw.circle(screen, point[5], (int(perspective_x), int(perspective_y)), perspective_size)

    # 将pygame的Surface转换为numpy数组
    frame_array = pygame.surfarray.array3d(screen)
    frame_array = np.rot90(frame_array, 1)  # 旋转图像以匹配视频方向

    # 将帧写入视频
    video_writer.write(frame_array)

    # 打印进度
    print(f"Generating frame {frame + 1}/{num_frames}")

# 释放视频写入器
video_writer.release()

print(f"Video saved to {video_name}")
# Out:
# Generating frame 1/450
# Generating frame 2/450
# Generating frame 3/450
# Generating frame 4/450
# Generating frame 5/450
# Generating frame 6/450
# Generating frame 7/450
# Generating frame 8/450
# Generating frame 9/450
# Generating frame 10/450
# Generating frame 11/450
# Generating frame 12/450
# Generating frame 13/450
# Generating frame 14/450
# Generating frame 15/450
# Generating frame 16/450
# Generating frame 17/450
# Generating frame 18/450
# Generating frame 19/450
# Generating frame 20/450
# Generating frame 21/450
# Generating frame 22/450
# Generating frame 23/450
# Generating frame 24/450
# Generating frame 25/450
# Generating frame 26/450
# Generating frame 27/450
# Generating frame 28/450
# Generating frame 29/450
# Generating frame 30/450
# Generating frame 31/450
# Generating frame 32/450
# Generating frame 33/450
# Generating frame 34/450
# Generating frame 35/450
# Generating frame 36/450
# Generating frame 37/450
# Generating frame 38/450
# Generating frame 39/450
# Generating frame 40/450
# Generating frame 41/450
# Generating frame 42/450
# Generating frame 43/450
# Generating frame 44/450
# Generating frame 45/450
# Generating frame 46/450
# Generating frame 47/450
# Generating frame 48/450
# Generating frame 49/450
# Generating frame 50/450
# Generating frame 51/450
# Generating frame 52/450
# Generating frame 53/450
# Generating frame 54/450
# Generating frame 55/450
# Generating frame 56/450
# Generating frame 57/450
# Generating frame 58/450
# Generating frame 59/450
# Generating frame 60/450
# Generating frame 61/450
# Generating frame 62/450
# Generating frame 63/450
# Generating frame 64/450
# Generating frame 65/450
# Generating frame 66/450
# Generating frame 67/450
# Generating frame 68/450
# Generating frame 69/450
# Generating frame 70/450
# Generating frame 71/450
# Generating frame 72/450
# Generating frame 73/450
# Generating frame 74/450
# Generating frame 75/450
# Generating frame 76/450
# Generating frame 77/450
# Generating frame 78/450
# Generating frame 79/450
# Generating frame 80/450
# Generating frame 81/450
# Generating frame 82/450
# Generating frame 83/450
# Generating frame 84/450
# Generating frame 85/450
# Generating frame 86/450
# Generating frame 87/450
# Generating frame 88/450
# Generating frame 89/450
# Generating frame 90/450
# Generating frame 91/450
# Generating frame 92/450
# Generating frame 93/450
# Generating frame 94/450
# Generating frame 95/450
# Generating frame 96/450
# Generating frame 97/450
# Generating frame 98/450
# Generating frame 99/450
# Generating frame 100/450
# Generating frame 101/450
# Generating frame 102/450
# Generating frame 103/450
# Generating frame 104/450
# Generating frame 105/450
# Generating frame 106/450
# Generating frame 107/450
# Generating frame 108/450
# Generating frame 109/450
# Generating frame 110/450
# Generating frame 111/450
# Generating frame 112/450
# Generating frame 113/450
# Generating frame 114/450
# Generating frame 115/450
# Generating frame 116/450
# Generating frame 117/450
# Generating frame 118/450
# Generating frame 119/450
# Generating frame 120/450
# Generating frame 121/450
# Generating frame 122/450
# Generating frame 123/450
# Generating frame 124/450
# Generating frame 125/450
# Generating frame 126/450
# Generating frame 127/450
# Generating frame 128/450
# Generating frame 129/450
# Generating frame 130/450
# Generating frame 131/450
# Generating frame 132/450
# Generating frame 133/450
# Generating frame 134/450
# Generating frame 135/450
# Generating frame 136/450
# Generating frame 137/450
# Generating frame 138/450
# Generating frame 139/450
# Generating frame 140/450
# Generating frame 141/450
# Generating frame 142/450
# Generating frame 143/450
# Generating frame 144/450
# Generating frame 145/450
# Generating frame 146/450
# Generating frame 147/450
# Generating frame 148/450
# Generating frame 149/450
# Generating frame 150/450
# Generating frame 151/450
# Generating frame 152/450
# Generating frame 153/450
# Generating frame 154/450
# Generating frame 155/450
# Generating frame 156/450
# Generating frame 157/450
# Generating frame 158/450
# Generating frame 159/450
# Generating frame 160/450
# Generating frame 161/450
# Generating frame 162/450
# Generating frame 163/450
# Generating frame 164/450
# Generating frame 165/450
# Generating frame 166/450
# Generating frame 167/450
# Generating frame 168/450
# Generating frame 169/450
# Generating frame 170/450
# Generating frame 171/450
# Generating frame 172/450
# Generating frame 173/450
# Generating frame 174/450
# Generating frame 175/450
# Generating frame 176/450
# Generating frame 177/450
# Generating frame 178/450
# Generating frame 179/450
# Generating frame 180/450
# Generating frame 181/450
# Generating frame 182/450
# Generating frame 183/450
# Generating frame 184/450
# Generating frame 185/450
# Generating frame 186/450
# Generating frame 187/450
# Generating frame 188/450
# Generating frame 189/450
# Generating frame 190/450
# Generating frame 191/450
# Generating frame 192/450
# Generating frame 193/450
# Generating frame 194/450
# Generating frame 195/450
# Generating frame 196/450
# Generating frame 197/450
# Generating frame 198/450
# Generating frame 199/450
# Generating frame 200/450
# Generating frame 201/450
# Generating frame 202/450
# Generating frame 203/450
# Generating frame 204/450
# Generating frame 205/450
# Generating frame 206/450
# Generating frame 207/450
# Generating frame 208/450
# Generating frame 209/450
# Generating frame 210/450
# Generating frame 211/450
# Generating frame 212/450
# Generating frame 213/450
# Generating frame 214/450
# Generating frame 215/450
# Generating frame 216/450
# Generating frame 217/450
# Generating frame 218/450
# Generating frame 219/450
# Generating frame 220/450
# Generating frame 221/450
# Generating frame 222/450
# Generating frame 223/450
# Generating frame 224/450
# Generating frame 225/450
# Generating frame 226/450
# Generating frame 227/450
# Generating frame 228/450
# Generating frame 229/450
# Generating frame 230/450
# Generating frame 231/450
# Generating frame 232/450
# Generating frame 233/450
# Generating frame 234/450
# Generating frame 235/450
# Generating frame 236/450
# Generating frame 237/450
# Generating frame 238/450
# Generating frame 239/450
# Generating frame 240/450
# Generating frame 241/450
# Generating frame 242/450
# Generating frame 243/450
# Generating frame 244/450
# Generating frame 245/450
# Generating frame 246/450
# Generating frame 247/450
# Generating frame 248/450
# Generating frame 249/450
# Generating frame 250/450
# Generating frame 251/450
# Generating frame 252/450
# Generating frame 253/450
# Generating frame 254/450
# Generating frame 255/450
# Generating frame 256/450
# Generating frame 257/450
# Generating frame 258/450
# Generating frame 259/450
# Generating frame 260/450
# Generating frame 261/450
# Generating frame 262/450
# Generating frame 263/450
# Generating frame 264/450
# Generating frame 265/450
# Generating frame 266/450
# Generating frame 267/450
# Generating frame 268/450
# Generating frame 269/450
# Generating frame 270/450
# Generating frame 271/450
# Generating frame 272/450
# Generating frame 273/450
# Generating frame 274/450
# Generating frame 275/450
# Generating frame 276/450
# Generating frame 277/450
# Generating frame 278/450
# Generating frame 279/450
# Generating frame 280/450
# Generating frame 281/450
# Generating frame 282/450
# Generating frame 283/450
# Generating frame 284/450
# Generating frame 285/450
# Generating frame 286/450
# Generating frame 287/450
# Generating frame 288/450
# Generating frame 289/450
# Generating frame 290/450
# Generating frame 291/450
# Generating frame 292/450
# Generating frame 293/450
# Generating frame 294/450
# Generating frame 295/450
# Generating frame 296/450
# Generating frame 297/450
# Generating frame 298/450
# Generating frame 299/450
# Generating frame 300/450
# Generating frame 301/450
# Generating frame 302/450
# Generating frame 303/450
# Generating frame 304/450
# Generating frame 305/450
# Generating frame 306/450
# Generating frame 307/450
# Generating frame 308/450
# Generating frame 309/450
# Generating frame 310/450
# Generating frame 311/450
# Generating frame 312/450
# Generating frame 313/450
# Generating frame 314/450
# Generating frame 315/450
# Generating frame 316/450
# Generating frame 317/450
# Generating frame 318/450
# Generating frame 319/450
# Generating frame 320/450
# Generating frame 321/450
# Generating frame 322/450
# Generating frame 323/450
# Generating frame 324/450
# Generating frame 325/450
# Generating frame 326/450
# Generating frame 327/450
# Generating frame 328/450
# Generating frame 329/450
# Generating frame 330/450
# Generating frame 331/450
# Generating frame 332/450
# Generating frame 333/450
# Generating frame 334/450
# Generating frame 335/450
# Generating frame 336/450
# Generating frame 337/450
# Generating frame 338/450
# Generating frame 339/450
# Generating frame 340/450
# Generating frame 341/450
# Generating frame 342/450
# Generating frame 343/450
# Generating frame 344/450
# Generating frame 345/450
# Generating frame 346/450
# Generating frame 347/450
# Generating frame 348/450
# Generating frame 349/450
# Generating frame 350/450
# Generating frame 351/450
# Generating frame 352/450
# Generating frame 353/450
# Generating frame 354/450
# Generating frame 355/450
# Generating frame 356/450
# Generating frame 357/450
# Generating frame 358/450
# Generating frame 359/450
# Generating frame 360/450
# Generating frame 361/450
# Generating frame 362/450
# Generating frame 363/450
# Generating frame 364/450
# Generating frame 365/450
# Generating frame 366/450
# Generating frame 367/450
# Generating frame 368/450
# Generating frame 369/450
# Generating frame 370/450
# Generating frame 371/450
# Generating frame 372/450
# Generating frame 373/450
# Generating frame 374/450
# Generating frame 375/450
# Generating frame 376/450
# Generating frame 377/450
# Generating frame 378/450
# Generating frame 379/450
# Generating frame 380/450
# Generating frame 381/450
# Generating frame 382/450
# Generating frame 383/450
# Generating frame 384/450
# Generating frame 385/450
# Generating frame 386/450
# Generating frame 387/450
# Generating frame 388/450
# Generating frame 389/450
# Generating frame 390/450
# Generating frame 391/450
# Generating frame 392/450
# Generating frame 393/450
# Generating frame 394/450
# Generating frame 395/450
# Generating frame 396/450
# Generating frame 397/450
# Generating frame 398/450
# Generating frame 399/450
# Generating frame 400/450
# Generating frame 401/450
# Generating frame 402/450
# Generating frame 403/450
# Generating frame 404/450
# Generating frame 405/450
# Generating frame 406/450
# Generating frame 407/450
# Generating frame 408/450
# Generating frame 409/450
# Generating frame 410/450
# Generating frame 411/450
# Generating frame 412/450
# Generating frame 413/450
# Generating frame 414/450
# Generating frame 415/450
# Generating frame 416/450
# Generating frame 417/450
# Generating frame 418/450
# Generating frame 419/450
# Generating frame 420/450
# Generating frame 421/450
# Generating frame 422/450
# Generating frame 423/450
# Generating frame 424/450
# Generating frame 425/450
# Generating frame 426/450
# Generating frame 427/450
# Generating frame 428/450
# Generating frame 429/450
# Generating frame 430/450
# Generating frame 431/450
# Generating frame 432/450
# Generating frame 433/450
# Generating frame 434/450
# Generating frame 435/450
# Generating frame 436/450
# Generating frame 437/450
# Generating frame 438/450
# Generating frame 439/450
# Generating frame 440/450
# Generating frame 441/450
# Generating frame 442/450
# Generating frame 443/450
# Generating frame 444/450
# Generating frame 445/450
# Generating frame 446/450
# Generating frame 447/450
# Generating frame 448/450
# Generating frame 449/450
# Generating frame 450/450
# Video saved to output_video/cosmic_simulation_20250619_191103.mp4

# %%
import cv2
import numpy as np
import random

# 设置视频参数
WIDTH, HEIGHT = 800, 600
FPS = 30
DURATION = 15  # 视频时长（秒）
NUM_FRAMES = FPS * DURATION  # 总帧数

# 加载图片
image_paths = ["1.jpg", "2.png", "3.jpg"]  # 替换为你的图片路径
images = []
for img_path in image_paths:
    img = cv2.imread(img_path)
    if img is None:
        raise FileNotFoundError(f"图片文件未找到: {img_path}")
    # 调整图片大小以填满屏幕
    img = cv2.resize(img, (WIDTH, HEIGHT))
    images.append(img)

# 初始化视频写入器
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
video_writer = cv2.VideoWriter('output.mp4', fourcc, FPS, (WIDTH, HEIGHT))

# 图片初始位置和速度
positions = []
speeds = []
entry_frames = []  # 每张图片进入屏幕的帧号

for i in range(len(images)):
    # 初始位置在屏幕外
    side = random.randint(0, 3)  # 0: 上, 1: 右, 2: 下, 3: 左
    if side == 0:
        x = random.randint(0, WIDTH)
        y = -HEIGHT
    elif side == 1:
        x = WIDTH
        y = random.randint(0, HEIGHT)
    elif side == 2:
        x = random.randint(0, WIDTH)
        y = HEIGHT
    else:
        x = -WIDTH
        y = random.randint(0, HEIGHT)
    positions.append([x, y])
    
    # 随机速度
    speed = random.uniform(2.0, 5.0)
    speeds.append(speed)
    
    # 随机确定图片进入屏幕的帧号
    entry_frame = random.randint(0, NUM_FRAMES // 2)
    entry_frames.append(entry_frame)

# 创建视频帧
for frame_idx in range(NUM_FRAMES):
    # 创建空白帧（默认为黑色背景）
    frame = np.zeros((HEIGHT, WIDTH, 3), dtype=np.uint8)
    
    for i in range(len(images)):
        entry_frame = entry_frames[i]
        if frame_idx >= entry_frame:
            x, y = positions[i]
            speed = speeds[i]
            
            # 更新位置
            x += speed
            y += speed
            
            # 检查是否完全进入屏幕
            if (x >= -WIDTH and x <= 0 and y >= -HEIGHT and y <= 0) or \
               (x + WIDTH >= 0 and x + WIDTH <= WIDTH and y + HEIGHT >= 0 and y + HEIGHT <= HEIGHT):
                # 绘制图片
                img = images[i]
                img_height, img_width = img.shape[:2]
                
                x_start = int(max(0, x))
                y_start = int(max(0, y))
                x_end = int(min(WIDTH, x + img_width))
                y_end = int(min(HEIGHT, y + img_height))
                
                if x_start < x_end and y_start < y_end:
                    frame[y_start:y_end, x_start:x_end] = img[
                        :y_end - y_start, :x_end - x_start
                    ]
            
            # 检查是否完全进入屏幕并填满
            if x + WIDTH >= WIDTH and x <= 0 and y + HEIGHT >= HEIGHT and y <= 0:
                positions[i] = [0, 0]  # 重置位置到屏幕中心（可选）
                speeds[i] = 0  # 停止移动（可选）
    
    # 写入帧到视频
    video_writer.write(frame)

# 释放资源
video_writer.release()
