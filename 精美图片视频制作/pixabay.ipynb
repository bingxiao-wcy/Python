# %%
import os
from PIL import Image
import shutil
import imagehash

# 遍历文件夹及其子目录下的所有图片
def traverse_images(folder):
    image_paths = []
    for root, dirs, files in os.walk(folder):
        for filename in files:
            if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif', '.webp')):
                image_paths.append(os.path.join(root, filename))
    return image_paths

# 获取图片的像素大小信息
def get_image_pixel_info(img_path):
    try:
        with Image.open(img_path) as img:
            width, height = img.size
            return (height, width)
    except Exception as e:
        print(f"获取图片像素信息时出错: {img_path} - {e}")
        return None

# 去除源文件夹中的重复图片
def remove_duplicate_images(source_folder):
    # 统计每个子文件夹的处理情况
    folder_stats = {}  # {folder_path: (processed, deleted)}

    # 遍历源文件夹及其子目录下的所有图片
    all_image_paths = traverse_images(source_folder)

    # 按文件夹分组图片
    folder_images = {}
    for img_path in all_image_paths:
        folder = os.path.dirname(img_path)
        if folder not in folder_images:
            folder_images[folder] = []
        folder_images[folder].append(img_path)

    # 按文件夹处理图片
    for folder, image_paths in folder_images.items():
        # 存储哈希值和对应的文件路径
        hash_dict = {}
        processed = 0
        deleted = 0

        # 按排序后的图片处理
        for img_path in image_paths:
            processed += 1
            try:
                # 打开图片并计算其哈希值
                with Image.open(img_path) as img:
                    img_hash = imagehash.phash(img)
                    # 检查是否是重复图片
                    if img_hash in hash_dict:
                        # 删除重复图片
                        os.remove(img_path)
                        deleted += 1
                    else:
                        # 保留第一个出现的图片
                        hash_dict[img_hash] = img_path
            except Exception as e:
                # 如果处理失败，保留文件但不算作有效图片
                print(f"处理图片时出错: {img_path} - {e}")

        # 记录统计信息
        folder_stats[folder] = (processed, deleted)

    # 打印最终的统计信息
    print("去重完成 - 总计:")
    print(f"  处理文件夹: {len(folder_stats)}")
    print(f"  总处理图片: {sum(p for p, d in folder_stats.values())}")
    print(f"  总删除图片: {sum(d for p, d in folder_stats.values())}")
    
    # 逐个文件夹统计
    print("\n每个文件夹统计:")
    for folder, (processed, deleted) in folder_stats.items():
        print(f"  {os.path.relpath(folder, source_folder)}: 处理 {processed} 张，删除 {deleted} 张")

# 按横竖像素和分类图片并处理
def categorize_images_by_pixel_sum(source_folder, target_folder):
    # 创建目标文件夹（如果不存在）
    if not os.path.exists(target_folder):
        os.makedirs(target_folder)
    
    # 创建原始图片备份文件夹
    original_folder = os.path.join(target_folder, "original")
    if not os.path.exists(original_folder):
        os.makedirs(original_folder)
    
    # 获取源文件夹中所有图片
    all_image_paths = traverse_images(source_folder)
    
    # 备份原始图片
    for img_path in all_image_paths:
        # 获取文件名和扩展名
        filename = os.path.basename(img_path)
        file_root, file_ext = os.path.splitext(filename)
        
        # 创建新文件名（避免同名文件冲突）
        new_filename = f"{file_root}{file_ext}"
        new_path = os.path.join(original_folder, new_filename)
        count = 1
        while os.path.exists(new_path):
            new_filename = f"{file_root}_{count}{file_ext}"
            new_path = os.path.join(original_folder, new_filename)
            count += 1
        
        # 复制文件到原始图片备份文件夹
        shutil.copy2(img_path, new_path)
    
    print(f"原始图片已备份到 '{original_folder}' 文件夹。")
    
    # 创建一个字典来存储每个像素和对应的图片列表
    pixel_sum_dict = {}
    
    for img_path in all_image_paths:
        pixel_info = get_image_pixel_info(img_path)
        if pixel_info:
            height, width = pixel_info
            pixel_sum = height + width
            
            # 找到合适的分类
            found_category = False
            for existing_sum in pixel_sum_dict.keys():
                if abs(existing_sum - pixel_sum) <= 30:
                    pixel_sum_dict[existing_sum].append(img_path)
                    found_category = True
                    break
            
            if not found_category:
                pixel_sum_dict[pixel_sum] = [img_path]
    
    # 处理每个像素和对应的图片列表
    for pixel_sum, img_paths in pixel_sum_dict.items():
        # 如果一类图片的个数超过10个，则创建独立文件夹
        if len(img_paths) > 10:
            category_folder = os.path.join(target_folder, f"sum_{pixel_sum}")
            if not os.path.exists(category_folder):
                os.makedirs(category_folder)
        else:
            category_folder = target_folder
        
        # 分类为宽图和长图
        wide_images = [img_path for img_path in img_paths if get_image_pixel_info(img_path)[1] > get_image_pixel_info(img_path)[0]]
        tall_images = [img_path for img_path in img_paths if get_image_pixel_info(img_path)[0] > get_image_pixel_info(img_path)[1]]

        # 按宽度排序（宽图）
        wide_images.sort(key=lambda x: get_image_pixel_info(x)[1])
        # 按高度排序（长图）
        tall_images.sort(key=lambda x: get_image_pixel_info(x)[0])

        # 将排序后的图片移动到对应的文件夹
        for img_path in wide_images + tall_images:
            filename = os.path.basename(img_path)
            new_path = os.path.join(category_folder, filename)
            shutil.move(img_path, new_path)
    
    print(f"图片已按横竖像素和分类到 '{target_folder}' 文件夹。")

# 按目录结构重命名图片
def rename_images_by_folder_structure(source_folder):
    # 用于记录每个目录下的图片计数
    folder_counts = {}

    # 遍历源文件夹及其子目录下的所有图片
    for root, dirs, files in os.walk(source_folder):
        for filename in files:
            if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif', '.webp')):
                img_path = os.path.join(root, filename)
                
                # 获取相对路径（用于构建新文件名）
                relative_path = os.path.relpath(root, source_folder)
                path_parts = relative_path.split(os.sep)
                
                # 构建新文件名（目录结构_序号.扩展名）
                new_filename_parts = []
                for part in path_parts:
                    # 只保留字母、数字和下划线
                    part = ''.join(c if c.isalnum() or c == '_' else '_' for c in part)
                    new_filename_parts.append(part)
                
                # 获取当前目录的计数
                folder_count = folder_counts.get(root, 1)
                
                # 构建新文件名
                file_root, file_ext = os.path.splitext(filename)
                new_filename = f"{'_'.join(new_filename_parts)}_{folder_count}{file_ext}"
                new_path = os.path.join(root, new_filename)
                
                # 更新目录计数
                folder_counts[root] = folder_count + 1
                
                # 重命名文件
                try:
                    os.rename(img_path, new_path)
                    print(f"已重命名: {img_path} -> {new_path}")
                except Exception as e:
                    print(f"重命名文件时出错: {img_path} -> {new_path} - {e}")

# 删除目标文件夹中的空目录
def remove_empty_folders(target_folder):
    # 遍历目标文件夹及其子目录
    for root, dirs, files in os.walk(target_folder, topdown=False):
        for folder in dirs:
            folder_path = os.path.join(root, folder)
            if not os.listdir(folder_path):  # 如果目录为空
                os.rmdir(folder_path)  # 删除空目录
                print(f"已删除空目录: {folder_path}")

# 主程序
if __name__ == "__main__":
    source_folder = "result"  # 源文件夹
    target_folder = os.path.join(source_folder, "classified")


    # 执行按横竖像素和分类图片
    categorize_images_by_pixel_sum(source_folder, target_folder)

    # 执行去重
    remove_duplicate_images(source_folder)
    
    # 执行按目录结构重命名图片
    rename_images_by_folder_structure(target_folder)
    
    # 删除目标文件夹中的空目录
    remove_empty_folders(target_folder)
# Out:
# 原始图片已备份到 'result\classified\original' 文件夹。
# 图片已按横竖像素和分类到 'result\classified' 文件夹。
# 去重完成 - 总计:
#   处理文件夹: 13
#   总处理图片: 2876
#   总删除图片: 1346
#
# 每个文件夹统计:
#   classified: 处理 35 张，删除 4 张
#   classified\original: 处理 1686 张，删除 922 张
#   classified\sum_1892: 处理 25 张，删除 12 张
#   classified\sum_1997: 处理 248 张，删除 115 张
#   classified\sum_2088: 处理 11 张，删除 5 张
#   classified\sum_2133: 处理 436 张，删除 195 张
#   classified\sum_2170: 处理 11 张，删除 5 张
#   classified\sum_2204: 处理 20 张，删除 10 张
#   classified\sum_2244: 处理 77 张，删除 38 张
#   classified\sum_2276: 处理 33 张，删除 17 张
#   classified\sum_2318: 处理 25 张，删除 12 张
#   classified\sum_2409: 处理 22 张，删除 11 张
#   classified\sum_2560: 处理 247 张，删除 0 张
# 已重命名: result\classified\ai-generated-7953404_1280.png -> result\classified\__1.png
# 已重命名: result\classified\ai-generated-7953406_1280.png -> result\classified\__2.png
# 已重命名: result\classified\ai-generated-8361970_1280.png -> result\classified\__3.png
# 已重命名: result\classified\ai-generated-8609619_1280.png -> result\classified\__4.png
# 已重命名: result\classified\ai-generated-8811381_1280.png -> result\classified\__5.png
# 已重命名: result\classified\ai-generated-8811383_1280.png -> result\classified\__6.png
# 已重命名: result\classified\ai-generated-8811384_1280.png -> result\classified\__7.png
# 已重命名: result\classified\ai-generated-8817349_1280.png -> result\classified\__8.png
# 已重命名: result\classified\ai-generated-8892916_1280.jpg -> result\classified\__9.jpg
# 已重命名: result\classified\ai-generated-8892917_1280.jpg -> result\classified\__10.jpg
# 已重命名: result\classified\ai-generated-8894407_1280.jpg -> result\classified\__11.jpg
# 已重命名: result\classified\ai-generated-8895035_1280.jpg -> result\classified\__12.jpg
# 已重命名: result\classified\ai-generated-8895038_1280.jpg -> result\classified\__13.jpg
# 已重命名: result\classified\ai-generated-8909643_1280.jpg -> result\classified\__14.jpg
# 已重命名: result\classified\ai-generated-8909644_1280.jpg -> result\classified\__15.jpg
# 已重命名: result\classified\ai-generated-8909647_1280.jpg -> result\classified\__16.jpg
# 已重命名: result\classified\ai-generated-9082959_1280.png -> result\classified\__17.png
# 已重命名: result\classified\ai-generated-9306969_1280.jpg -> result\classified\__18.jpg
# 已重命名: result\classified\floral-8147725_1280.png -> result\classified\__19.png
# 已重命名: result\classified\fruit-8808554_1280.png -> result\classified\__20.png
# 已重命名: result\classified\fruit-8808563_1280.png -> result\classified\__21.png
# 已重命名: result\classified\mandala-8596506_1280.png -> result\classified\__22.png
# 已重命名: result\classified\nature-9133897_1280.jpg -> result\classified\__23.jpg
# 已重命名: result\classified\original_443.png -> result\classified\__24.png
# 已重命名: result\classified\original_488.jpg -> result\classified\__25.jpg
# 已重命名: result\classified\original_510.jpg -> result\classified\__26.jpg
# 已重命名: result\classified\original_609.png -> result\classified\__27.png
# 已重命名: result\classified\original_648.png -> result\classified\__28.png
# 已重命名: result\classified\supernatural-8868447_1280.png -> result\classified\__29.png
# 已重命名: result\classified\supernatural-8868452_1280.png -> result\classified\__30.png
# 已重命名: result\classified\supernatural-8868455_1280.png -> result\classified\__31.png
# 已重命名: result\classified\original\abstract-8817337_1280.png -> result\classified\original\original_1.png
# 已重命名: result\classified\original\abstract-8817340_1280.png -> result\classified\original\original_2.png
# 已重命名: result\classified\original\abstract-8817342_1280.png -> result\classified\original\original_3.png
# 重命名文件时出错: result\classified\original\ai-generated-7747142_1280.jpg -> result\classified\original\original_4.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\ai-generated-7747142_1280.jpg' -> 'result\\classified\\original\\original_4.jpg'
# 已重命名: result\classified\original\ai-generated-7953404_1280.png -> result\classified\original\original_5.png
# 已重命名: result\classified\original\ai-generated-7953406_1280.png -> result\classified\original\original_6.png
# 已重命名: result\classified\original\ai-generated-8156643_1280.jpg -> result\classified\original\original_7.jpg
# 重命名文件时出错: result\classified\original\ai-generated-8302596_1280.jpg -> result\classified\original\original_8.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\ai-generated-8302596_1280.jpg' -> 'result\\classified\\original\\original_8.jpg'
# 已重命名: result\classified\original\ai-generated-8310861_1280.png -> result\classified\original\original_9.png
# 已重命名: result\classified\original\ai-generated-8347692_1280.png -> result\classified\original\original_10.png
# 已重命名: result\classified\original\ai-generated-8361970_1280.png -> result\classified\original\original_11.png
# 已重命名: result\classified\original\ai-generated-8428856_1280.png -> result\classified\original\original_12.png
# 已重命名: result\classified\original\ai-generated-8480822_1280.png -> result\classified\original\original_13.png
# 重命名文件时出错: result\classified\original\ai-generated-8515013_1280.jpg -> result\classified\original\original_14.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\ai-generated-8515013_1280.jpg' -> 'result\\classified\\original\\original_14.jpg'
# 重命名文件时出错: result\classified\original\ai-generated-8548348_1280.png -> result\classified\original\original_15.png - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\ai-generated-8548348_1280.png' -> 'result\\classified\\original\\original_15.png'
# 已重命名: result\classified\original\ai-generated-8609619_1280.png -> result\classified\original\original_16.png
# 已重命名: result\classified\original\ai-generated-8613606_1280.png -> result\classified\original\original_17.png
# 已重命名: result\classified\original\ai-generated-8629743_1280.png -> result\classified\original\original_18.png
# 已重命名: result\classified\original\ai-generated-8658030_1280.jpg -> result\classified\original\original_19.jpg
# 已重命名: result\classified\original\ai-generated-8664748_1280.png -> result\classified\original\original_20.png
# 已重命名: result\classified\original\ai-generated-8675021_1280.png -> result\classified\original\original_21.png
# 已重命名: result\classified\original\ai-generated-8685246_1280.jpg -> result\classified\original\original_22.jpg
# 已重命名: result\classified\original\ai-generated-8696546_1280.png -> result\classified\original\original_23.png
# 重命名文件时出错: result\classified\original\ai-generated-8707465_1280.jpg -> result\classified\original\original_24.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\ai-generated-8707465_1280.jpg' -> 'result\\classified\\original\\original_24.jpg'
# 已重命名: result\classified\original\ai-generated-8723795_1280.png -> result\classified\original\original_25.png
# 重命名文件时出错: result\classified\original\ai-generated-8774178_1280.jpg -> result\classified\original\original_26.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\ai-generated-8774178_1280.jpg' -> 'result\\classified\\original\\original_26.jpg'
# 已重命名: result\classified\original\ai-generated-8774179_1280.jpg -> result\classified\original\original_27.jpg
# 已重命名: result\classified\original\ai-generated-8774186_1280.jpg -> result\classified\original\original_28.jpg
# 已重命名: result\classified\original\ai-generated-8774189_1280.jpg -> result\classified\original\original_29.jpg
# 重命名文件时出错: result\classified\original\ai-generated-8774197_1280.jpg -> result\classified\original\original_30.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\ai-generated-8774197_1280.jpg' -> 'result\\classified\\original\\original_30.jpg'
# 已重命名: result\classified\original\ai-generated-8774198_1280.jpg -> result\classified\original\original_31.jpg
# 重命名文件时出错: result\classified\original\ai-generated-8774202_1280.jpg -> result\classified\original\original_32.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\ai-generated-8774202_1280.jpg' -> 'result\\classified\\original\\original_32.jpg'
# 已重命名: result\classified\original\ai-generated-8774203_1280.jpg -> result\classified\original\original_33.jpg
# 已重命名: result\classified\original\ai-generated-8774208_1280.jpg -> result\classified\original\original_34.jpg
# 已重命名: result\classified\original\ai-generated-8774634_1280.jpg -> result\classified\original\original_35.jpg
# 已重命名: result\classified\original\ai-generated-8774638_1280.jpg -> result\classified\original\original_36.jpg
# 已重命名: result\classified\original\ai-generated-8774648_1280.jpg -> result\classified\original\original_37.jpg
# 已重命名: result\classified\original\ai-generated-8806962_1280.png -> result\classified\original\original_38.png
# 已重命名: result\classified\original\ai-generated-8806963_1280.png -> result\classified\original\original_39.png
# 重命名文件时出错: result\classified\original\ai-generated-8806965_1280.png -> result\classified\original\original_40.png - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\ai-generated-8806965_1280.png' -> 'result\\classified\\original\\original_40.png'
# 已重命名: result\classified\original\ai-generated-8806966_1280.png -> result\classified\original\original_41.png
# 已重命名: result\classified\original\ai-generated-8807348_1280.png -> result\classified\original\original_42.png
# 已重命名: result\classified\original\ai-generated-8807349_1280.png -> result\classified\original\original_43.png
# 已重命名: result\classified\original\ai-generated-8807351_1280.png -> result\classified\original\original_44.png
# 已重命名: result\classified\original\ai-generated-8811381_1280.png -> result\classified\original\original_45.png
# 已重命名: result\classified\original\ai-generated-8811383_1280.png -> result\classified\original\original_46.png
# 已重命名: result\classified\original\ai-generated-8811384_1280.png -> result\classified\original\original_47.png
# 已重命名: result\classified\original\ai-generated-8817349_1280.png -> result\classified\original\original_48.png
# 已重命名: result\classified\original\ai-generated-8817367_1280.png -> result\classified\original\original_49.png
# 重命名文件时出错: result\classified\original\ai-generated-8852649_1280 (1).png -> result\classified\original\original_50.png - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\ai-generated-8852649_1280 (1).png' -> 'result\\classified\\original\\original_50.png'
# 已重命名: result\classified\original\ai-generated-8878297_1280.png -> result\classified\original\original_51.png
# 已重命名: result\classified\original\ai-generated-8878299_1280.png -> result\classified\original\original_52.png
# 已重命名: result\classified\original\ai-generated-8878302_1280.png -> result\classified\original\original_53.png
# 重命名文件时出错: result\classified\original\ai-generated-8878303_1280.png -> result\classified\original\original_54.png - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\ai-generated-8878303_1280.png' -> 'result\\classified\\original\\original_54.png'
# 已重命名: result\classified\original\ai-generated-8878304_1280.png -> result\classified\original\original_55.png
# 已重命名: result\classified\original\ai-generated-8892475_1280.jpg -> result\classified\original\original_56.jpg
# 已重命名: result\classified\original\ai-generated-8892916_1280.jpg -> result\classified\original\original_57.jpg
# 已重命名: result\classified\original\ai-generated-8892917_1280.jpg -> result\classified\original\original_58.jpg
# 已重命名: result\classified\original\ai-generated-8894407_1280.jpg -> result\classified\original\original_59.jpg
# 已重命名: result\classified\original\ai-generated-8895035_1280.jpg -> result\classified\original\original_60.jpg
# 已重命名: result\classified\original\ai-generated-8895038_1280.jpg -> result\classified\original\original_61.jpg
# 已重命名: result\classified\original\ai-generated-8909643_1280.jpg -> result\classified\original\original_62.jpg
# 已重命名: result\classified\original\ai-generated-8909644_1280.jpg -> result\classified\original\original_63.jpg
# 重命名文件时出错: result\classified\original\ai-generated-8909647_1280.jpg -> result\classified\original\original_64.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\ai-generated-8909647_1280.jpg' -> 'result\\classified\\original\\original_64.jpg'
# 已重命名: result\classified\original\ai-generated-9054173_1280.jpg -> result\classified\original\original_65.jpg
# 已重命名: result\classified\original\ai-generated-9054833_1280.png -> result\classified\original\original_66.png
# 已重命名: result\classified\original\ai-generated-9082959_1280.png -> result\classified\original\original_67.png
# 已重命名: result\classified\original\ai-generated-9102218_1280.png -> result\classified\original\original_68.png
# 重命名文件时出错: result\classified\original\ai-generated-9130538_1280.jpg -> result\classified\original\original_69.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\ai-generated-9130538_1280.jpg' -> 'result\\classified\\original\\original_69.jpg'
# 已重命名: result\classified\original\ai-generated-9164039_1280.png -> result\classified\original\original_70.png
# 重命名文件时出错: result\classified\original\ai-generated-9306969_1280.jpg -> result\classified\original\original_71.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\ai-generated-9306969_1280.jpg' -> 'result\\classified\\original\\original_71.jpg'
# 重命名文件时出错: result\classified\original\ai-generated-9587204_1280 (1).jpg -> result\classified\original\original_72.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\ai-generated-9587204_1280 (1).jpg' -> 'result\\classified\\original\\original_72.jpg'
# 重命名文件时出错: result\classified\original\apple-8813528_1280.png -> result\classified\original\original_73.png - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\apple-8813528_1280.png' -> 'result\\classified\\original\\original_73.png'
# 已重命名: result\classified\original\apple-8813529_1280.png -> result\classified\original\original_74.png
# 已重命名: result\classified\original\apple-8813530_1280.png -> result\classified\original\original_75.png
# 已重命名: result\classified\original\apple-8813532_1280.png -> result\classified\original\original_76.png
# 已重命名: result\classified\original\apple-8816835_1280.png -> result\classified\original\original_77.png
# 已重命名: result\classified\original\cakes-9026216_1280.png -> result\classified\original\original_78.png
# 已重命名: result\classified\original\christmas-9202493_1280.jpg -> result\classified\original\original_79.jpg
# 已重命名: result\classified\original\coconut-8802608_1280.png -> result\classified\original\original_80.png
# 重命名文件时出错: result\classified\original\coconut-8802609_1280.png -> result\classified\original\original_81.png - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\coconut-8802609_1280.png' -> 'result\\classified\\original\\original_81.png'
# 已重命名: result\classified\original\coconut-8802615_1280.png -> result\classified\original\original_82.png
# 已重命名: result\classified\original\coconut-8802616_1280.png -> result\classified\original\original_83.png
# 已重命名: result\classified\original\coconut-8803361_1280.png -> result\classified\original\original_84.png
# 已重命名: result\classified\original\coconut-8803362_1280.png -> result\classified\original\original_85.png
# 已重命名: result\classified\original\comic-8858229_1280.png -> result\classified\original\original_86.png
# 已重命名: result\classified\original\comic-8858230_1280.png -> result\classified\original\original_87.png
# 已重命名: result\classified\original\comic-8858232_1280.png -> result\classified\original\original_88.png
# 已重命名: result\classified\original\comic-8858233_1280.png -> result\classified\original\original_89.png
# 已重命名: result\classified\original\comic-8858234_1280.png -> result\classified\original\original_90.png
# 已重命名: result\classified\original\drink-8785346_1280 (1).png -> result\classified\original\original_91.png
# 已重命名: result\classified\original\fantasy-9326664_1280.png -> result\classified\original\original_92.png
# 重命名文件时出错: result\classified\original\floral-8147725_1280.png -> result\classified\original\original_93.png - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\floral-8147725_1280.png' -> 'result\\classified\\original\\original_93.png'
# 重命名文件时出错: result\classified\original\flower-8622942_1280.jpg -> result\classified\original\original_94.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\flower-8622942_1280.jpg' -> 'result\\classified\\original\\original_94.jpg'
# 已重命名: result\classified\original\flower-8774195_1280.jpg -> result\classified\original\original_95.jpg
# 已重命名: result\classified\original\flower-8774205_1280.jpg -> result\classified\original\original_96.jpg
# 已重命名: result\classified\original\flowers-8352615_1280.png -> result\classified\original\original_97.png
# 已重命名: result\classified\original\fruit-8808554_1280.png -> result\classified\original\original_98.png
# 已重命名: result\classified\original\fruit-8808563_1280.png -> result\classified\original\original_99.png
# 重命名文件时出错: result\classified\original\fruit-8813533_1280.png -> result\classified\original\original_100.png - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\fruit-8813533_1280.png' -> 'result\\classified\\original\\original_100.png'
# 重命名文件时出错: result\classified\original\hands-8789690_1280.png -> result\classified\original\original_101.png - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\hands-8789690_1280.png' -> 'result\\classified\\original\\original_101.png'
# 重命名文件时出错: result\classified\original\heart-8813534_1280.png -> result\classified\original\original_102.png - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\heart-8813534_1280.png' -> 'result\\classified\\original\\original_102.png'
# 重命名文件时出错: result\classified\original\lotus-8774344_1280.jpg -> result\classified\original\original_103.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\lotus-8774344_1280.jpg' -> 'result\\classified\\original\\original_103.jpg'
# 已重命名: result\classified\original\love-8813540_1280.png -> result\classified\original\original_104.png
# 已重命名: result\classified\original\love-8813541_1280.png -> result\classified\original\original_105.png
# 已重命名: result\classified\original\magical-8336392_1280.png -> result\classified\original\original_106.png
# 已重命名: result\classified\original\mandala-8596506_1280.png -> result\classified\original\original_107.png
# 重命名文件时出错: result\classified\original\nature-9133897_1280.jpg -> result\classified\original\original_108.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\nature-9133897_1280.jpg' -> 'result\\classified\\original\\original_108.jpg'
# 重命名文件时出错: result\classified\original\original_1.jpg -> result\classified\original\original_109.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\original_1.jpg' -> 'result\\classified\\original\\original_109.jpg'
# 已重命名: result\classified\original\original_10.jpg -> result\classified\original\original_110.jpg
# 已重命名: result\classified\original\original_100.png -> result\classified\original\original_111.png
# 已重命名: result\classified\original\original_101.png -> result\classified\original\original_112.png
# 已重命名: result\classified\original\original_102.png -> result\classified\original\original_113.png
# 重命名文件时出错: result\classified\original\original_103.jpg -> result\classified\original\original_114.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\original_103.jpg' -> 'result\\classified\\original\\original_114.jpg'
# 已重命名: result\classified\original\original_104.jpg -> result\classified\original\original_115.jpg
# 重命名文件时出错: result\classified\original\original_105.jpg -> result\classified\original\original_116.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\original_105.jpg' -> 'result\\classified\\original\\original_116.jpg'
# 已重命名: result\classified\original\original_106.jpg -> result\classified\original\original_117.jpg
# 已重命名: result\classified\original\original_107_1.png -> result\classified\original\original_118.png
# 重命名文件时出错: result\classified\original\original_108.jpg -> result\classified\original\original_119.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\original_108.jpg' -> 'result\\classified\\original\\original_119.jpg'
# 重命名文件时出错: result\classified\original\original_109.jpg -> result\classified\original\original_120.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\original_109.jpg' -> 'result\\classified\\original\\original_120.jpg'
# 重命名文件时出错: result\classified\original\original_110_1.jpg -> result\classified\original\original_121.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\original_110_1.jpg' -> 'result\\classified\\original\\original_121.jpg'
# 已重命名: result\classified\original\original_111_1.png -> result\classified\original\original_122.png
# 已重命名: result\classified\original\original_112.jpg -> result\classified\original\original_123.jpg
# 已重命名: result\classified\original\original_113_1.png -> result\classified\original\original_124.png
# 重命名文件时出错: result\classified\original\original_114.jpg -> result\classified\original\original_125.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\original_114.jpg' -> 'result\\classified\\original\\original_125.jpg'
# 已重命名: result\classified\original\original_115_1.png -> result\classified\original\original_126.png
# 已重命名: result\classified\original\original_115_1_1.jpg -> result\classified\original\original_127.jpg
# 重命名文件时出错: result\classified\original\original_116.jpg -> result\classified\original\original_128.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\original_116.jpg' -> 'result\\classified\\original\\original_128.jpg'
# 已重命名: result\classified\original\original_117.png -> result\classified\original\original_129.png
# 已重命名: result\classified\original\original_118.jpg -> result\classified\original\original_130.jpg
# 重命名文件时出错: result\classified\original\original_119.jpg -> result\classified\original\original_131.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\original_119.jpg' -> 'result\\classified\\original\\original_131.jpg'
# 重命名文件时出错: result\classified\original\original_11_1.png -> result\classified\original\original_132.png - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\original_11_1.png' -> 'result\\classified\\original\\original_132.png'
# 重命名文件时出错: result\classified\original\original_12.jpg -> result\classified\original\original_133.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\original_12.jpg' -> 'result\\classified\\original\\original_133.jpg'
# 重命名文件时出错: result\classified\original\original_120.jpg -> result\classified\original\original_134.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\original_120.jpg' -> 'result\\classified\\original\\original_134.jpg'
# 重命名文件时出错: result\classified\original\original_121.jpg -> result\classified\original\original_135.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\original_121.jpg' -> 'result\\classified\\original\\original_135.jpg'
# 重命名文件时出错: result\classified\original\original_122_1.jpg -> result\classified\original\original_136.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\original_122_1.jpg' -> 'result\\classified\\original\\original_136.jpg'
# 已重命名: result\classified\original\original_122_1_1.png -> result\classified\original\original_137.png
# 重命名文件时出错: result\classified\original\original_123.png -> result\classified\original\original_138.png - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\original_123.png' -> 'result\\classified\\original\\original_138.png'
# 重命名文件时出错: result\classified\original\original_124.jpg -> result\classified\original\original_139.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\original_124.jpg' -> 'result\\classified\\original\\original_139.jpg'
# 已重命名: result\classified\original\original_124_1_1.png -> result\classified\original\original_140.png
# 重命名文件时出错: result\classified\original\original_125.jpg -> result\classified\original\original_141.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\original_125.jpg' -> 'result\\classified\\original\\original_141.jpg'
# 重命名文件时出错: result\classified\original\original_126.jpg -> result\classified\original\original_142.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\original_126.jpg' -> 'result\\classified\\original\\original_142.jpg'
# 重命名文件时出错: result\classified\original\original_127.png -> result\classified\original\original_143.png - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\original_127.png' -> 'result\\classified\\original\\original_143.png'
# 已重命名: result\classified\original\original_128.jpg -> result\classified\original\original_144.jpg
# 已重命名: result\classified\original\original_129_1.png -> result\classified\original\original_145.png
# 重命名文件时出错: result\classified\original\original_12_1_1.jpg -> result\classified\original\original_146.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\original_12_1_1.jpg' -> 'result\\classified\\original\\original_146.jpg'
# 已重命名: result\classified\original\original_13.jpg -> result\classified\original\original_147.jpg
# 重命名文件时出错: result\classified\original\original_130_1.jpg -> result\classified\original\original_148.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\original_130_1.jpg' -> 'result\\classified\\original\\original_148.jpg'
# 重命名文件时出错: result\classified\original\original_131.jpg -> result\classified\original\original_149.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\original_131.jpg' -> 'result\\classified\\original\\original_149.jpg'
# 重命名文件时出错: result\classified\original\original_131_1_1.jpg -> result\classified\original\original_150.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\original_131_1_1.jpg' -> 'result\\classified\\original\\original_150.jpg'
# 重命名文件时出错: result\classified\original\original_132.jpg -> result\classified\original\original_151.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\original_132.jpg' -> 'result\\classified\\original\\original_151.jpg'
# 已重命名: result\classified\original\original_132.png -> result\classified\original\original_152.png
# 重命名文件时出错: result\classified\original\original_133.jpg -> result\classified\original\original_153.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\original_133.jpg' -> 'result\\classified\\original\\original_153.jpg'
# 重命名文件时出错: result\classified\original\original_134.jpg -> result\classified\original\original_154.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\original_134.jpg' -> 'result\\classified\\original\\original_154.jpg'
# 已重命名: result\classified\original\original_134.png -> result\classified\original\original_155.png
# 重命名文件时出错: result\classified\original\original_135.jpg -> result\classified\original\original_156.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\original_135.jpg' -> 'result\\classified\\original\\original_156.jpg'
# 重命名文件时出错: result\classified\original\original_136.jpg -> result\classified\original\original_157.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\original_136.jpg' -> 'result\\classified\\original\\original_157.jpg'
# 重命名文件时出错: result\classified\original\original_137.jpg -> result\classified\original\original_158.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\original_137.jpg' -> 'result\\classified\\original\\original_158.jpg'
# 重命名文件时出错: result\classified\original\original_138.png -> result\classified\original\original_159.png - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\original_138.png' -> 'result\\classified\\original\\original_159.png'
# 已重命名: result\classified\original\original_138_1_1.png -> result\classified\original\original_160.png
# 已重命名: result\classified\original\original_139.jpg -> result\classified\original\original_161.jpg
# 已重命名: result\classified\original\original_13_1_1.jpg -> result\classified\original\original_162.jpg
# 已重命名: result\classified\original\original_14.jpg -> result\classified\original\original_163.jpg
# 重命名文件时出错: result\classified\original\original_140.jpg -> result\classified\original\original_164.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\original_140.jpg' -> 'result\\classified\\original\\original_164.jpg'
# 已重命名: result\classified\original\original_140_1.png -> result\classified\original\original_165.png
# 已重命名: result\classified\original\original_141.jpg -> result\classified\original\original_166.jpg
# 已重命名: result\classified\original\original_141_1_1.jpg -> result\classified\original\original_167.jpg
# 重命名文件时出错: result\classified\original\original_142.jpg -> result\classified\original\original_168.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\original_142.jpg' -> 'result\\classified\\original\\original_168.jpg'
# 已重命名: result\classified\original\original_143.png -> result\classified\original\original_169.png
# 已重命名: result\classified\original\original_144_1.png -> result\classified\original\original_170.png
# 重命名文件时出错: result\classified\original\original_145_1.jpg -> result\classified\original\original_171.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\original_145_1.jpg' -> 'result\\classified\\original\\original_171.jpg'
# 已重命名: result\classified\original\original_146.jpg -> result\classified\original\original_172.jpg
# 已重命名: result\classified\original\original_147_1.png -> result\classified\original\original_173.png
# 重命名文件时出错: result\classified\original\original_148.jpg -> result\classified\original\original_174.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\original_148.jpg' -> 'result\\classified\\original\\original_174.jpg'
# 重命名文件时出错: result\classified\original\original_149.jpg -> result\classified\original\original_175.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\original_149.jpg' -> 'result\\classified\\original\\original_175.jpg'
# 已重命名: result\classified\original\original_15.png -> result\classified\original\original_176.png
# 已重命名: result\classified\original\original_150.jpg -> result\classified\original\original_177.jpg
# 重命名文件时出错: result\classified\original\original_150_1_1.jpg -> result\classified\original\original_178.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\original_150_1_1.jpg' -> 'result\\classified\\original\\original_178.jpg'
# 重命名文件时出错: result\classified\original\original_151.jpg -> result\classified\original\original_179.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\original_151.jpg' -> 'result\\classified\\original\\original_179.jpg'
# 已重命名: result\classified\original\original_151_1_1.png -> result\classified\original\original_180.png
# 已重命名: result\classified\original\original_152.jpg -> result\classified\original\original_181.jpg
# 重命名文件时出错: result\classified\original\original_152_1.png -> result\classified\original\original_182.png - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\original_152_1.png' -> 'result\\classified\\original\\original_182.png'
# 重命名文件时出错: result\classified\original\original_153.jpg -> result\classified\original\original_183.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\original_153.jpg' -> 'result\\classified\\original\\original_183.jpg'
# 已重命名: result\classified\original\original_153_1_1.png -> result\classified\original\original_184.png
# 已重命名: result\classified\original\original_154.jpg -> result\classified\original\original_185.jpg
# 已重命名: result\classified\original\original_155.jpg -> result\classified\original\original_186.jpg
# 已重命名: result\classified\original\original_155_1.png -> result\classified\original\original_187.png
# 已重命名: result\classified\original\original_156.jpg -> result\classified\original\original_188.jpg
# 重命名文件时出错: result\classified\original\original_156.png -> result\classified\original\original_189.png - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\original_156.png' -> 'result\\classified\\original\\original_189.png'
# 重命名文件时出错: result\classified\original\original_157.jpg -> result\classified\original\original_190.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\original_157.jpg' -> 'result\\classified\\original\\original_190.jpg'
# 重命名文件时出错: result\classified\original\original_157_1.png -> result\classified\original\original_191.png - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\original_157_1.png' -> 'result\\classified\\original\\original_191.png'
# 重命名文件时出错: result\classified\original\original_158.jpg -> result\classified\original\original_192.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\original_158.jpg' -> 'result\\classified\\original\\original_192.jpg'
# 已重命名: result\classified\original\original_159.jpg -> result\classified\original\original_193.jpg
# 重命名文件时出错: result\classified\original\original_159.png -> result\classified\original\original_194.png - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\original_159.png' -> 'result\\classified\\original\\original_194.png'
# 已重命名: result\classified\original\original_15_1_1.jpg -> result\classified\original\original_195.jpg
# 已重命名: result\classified\original\original_16.jpg -> result\classified\original\original_196.jpg
# 重命名文件时出错: result\classified\original\original_160_1.png -> result\classified\original\original_197.png - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\original_160_1.png' -> 'result\\classified\\original\\original_197.png'
# 重命名文件时出错: result\classified\original\original_161_1.jpg -> result\classified\original\original_198.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\original_161_1.jpg' -> 'result\\classified\\original\\original_198.jpg'
# 已重命名: result\classified\original\original_162_1.png -> result\classified\original\original_199.png
# 重命名文件时出错: result\classified\original\original_163_1.jpg -> result\classified\original\original_200.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\original_163_1.jpg' -> 'result\\classified\\original\\original_200.jpg'
# 已重命名: result\classified\original\original_164.jpg -> result\classified\original\original_201.jpg
# 已重命名: result\classified\original\original_165_1.png -> result\classified\original\original_202.png
# 已重命名: result\classified\original\original_166_1.jpg -> result\classified\original\original_203.jpg
# 已重命名: result\classified\original\original_167.png -> result\classified\original\original_204.png
# 已重命名: result\classified\original\original_168.jpg -> result\classified\original\original_205.jpg
# 已重命名: result\classified\original\original_169.jpg -> result\classified\original\original_206.jpg
# 已重命名: result\classified\original\original_170.jpg -> result\classified\original\original_207.jpg
# 已重命名: result\classified\original\original_171.jpg -> result\classified\original\original_208.jpg
# 重命名文件时出错: result\classified\original\original_172_1.png -> result\classified\original\original_209.png - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\original_172_1.png' -> 'result\\classified\\original\\original_209.png'
# 已重命名: result\classified\original\original_173.jpg -> result\classified\original\original_210.jpg
# 重命名文件时出错: result\classified\original\original_174.jpg -> result\classified\original\original_211.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\original_174.jpg' -> 'result\\classified\\original\\original_211.jpg'
# 已重命名: result\classified\original\original_175.jpg -> result\classified\original\original_212.jpg
# 已重命名: result\classified\original\original_175.png -> result\classified\original\original_213.png
# 重命名文件时出错: result\classified\original\original_176.jpg -> result\classified\original\original_214.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\original_176.jpg' -> 'result\\classified\\original\\original_214.jpg'
# 重命名文件时出错: result\classified\original\original_177_1.png -> result\classified\original\original_215.png - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\original_177_1.png' -> 'result\\classified\\original\\original_215.png'
# 已重命名: result\classified\original\original_178.jpg -> result\classified\original\original_216.jpg
# 已重命名: result\classified\original\original_178.png -> result\classified\original\original_217.png
# 已重命名: result\classified\original\original_179.jpg -> result\classified\original\original_218.jpg
# 已重命名: result\classified\original\original_18.jpg -> result\classified\original\original_219.jpg
# 已重命名: result\classified\original\original_181_1.png -> result\classified\original\original_220.png
# 已重命名: result\classified\original\original_182.png -> result\classified\original\original_221.png
# 已重命名: result\classified\original\original_183.jpg -> result\classified\original\original_222.jpg
# 重命名文件时出错: result\classified\original\original_184_1.png -> result\classified\original\original_223.png - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\original_184_1.png' -> 'result\\classified\\original\\original_223.png'
# 已重命名: result\classified\original\original_185.png -> result\classified\original\original_224.png
# 已重命名: result\classified\original\original_186.png -> result\classified\original\original_225.png
# 已重命名: result\classified\original\original_186_1_1.jpg -> result\classified\original\original_226.jpg
# 已重命名: result\classified\original\original_187.jpg -> result\classified\original\original_227.jpg
# 已重命名: result\classified\original\original_188_1.png -> result\classified\original\original_228.png
# 已重命名: result\classified\original\original_189.jpg -> result\classified\original\original_229.jpg
# 已重命名: result\classified\original\original_189.png -> result\classified\original\original_230.png
# 已重命名: result\classified\original\original_19.png -> result\classified\original\original_231.png
# 已重命名: result\classified\original\original_190.jpg -> result\classified\original\original_232.jpg
# 已重命名: result\classified\original\original_191.png -> result\classified\original\original_233.png
# 重命名文件时出错: result\classified\original\original_192.jpg -> result\classified\original\original_234.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\original_192.jpg' -> 'result\\classified\\original\\original_234.jpg'
# 已重命名: result\classified\original\original_193.png -> result\classified\original\original_235.png
# 已重命名: result\classified\original\original_194.png -> result\classified\original\original_236.png
# 已重命名: result\classified\original\original_195.png -> result\classified\original\original_237.png
# 已重命名: result\classified\original\original_196.png -> result\classified\original\original_238.png
# 已重命名: result\classified\original\original_197.png -> result\classified\original\original_239.png
# 已重命名: result\classified\original\original_198.jpg -> result\classified\original\original_240.jpg
# 已重命名: result\classified\original\original_198.png -> result\classified\original\original_241.png
# 已重命名: result\classified\original\original_199_1.jpg -> result\classified\original\original_242.jpg
# 已重命名: result\classified\original\original_2.jpg -> result\classified\original\original_243.jpg
# 已重命名: result\classified\original\original_20.jpg -> result\classified\original\original_244.jpg
# 已重命名: result\classified\original\original_200.jpg -> result\classified\original\original_245.jpg
# 已重命名: result\classified\original\original_201.png -> result\classified\original\original_246.png
# 已重命名: result\classified\original\original_202_1.png -> result\classified\original\original_247.png
# 已重命名: result\classified\original\original_203_1.png -> result\classified\original\original_248.png
# 已重命名: result\classified\original\original_204.jpg -> result\classified\original\original_249.jpg
# 已重命名: result\classified\original\original_205.png -> result\classified\original\original_250.png
# 已重命名: result\classified\original\original_206.png -> result\classified\original\original_251.png
# 已重命名: result\classified\original\original_207.png -> result\classified\original\original_252.png
# 已重命名: result\classified\original\original_209.png -> result\classified\original\original_253.png
# 已重命名: result\classified\original\original_21.jpg -> result\classified\original\original_254.jpg
# 已重命名: result\classified\original\original_210.png -> result\classified\original\original_255.png
# 重命名文件时出错: result\classified\original\original_211.jpg -> result\classified\original\original_256.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\original_211.jpg' -> 'result\\classified\\original\\original_256.jpg'
# 已重命名: result\classified\original\original_211.png -> result\classified\original\original_257.png
# 已重命名: result\classified\original\original_212.png -> result\classified\original\original_258.png
# 已重命名: result\classified\original\original_213_1.png -> result\classified\original\original_259.png
# 已重命名: result\classified\original\original_214.jpg -> result\classified\original\original_260.jpg
# 已重命名: result\classified\original\original_214.png -> result\classified\original\original_261.png
# 已重命名: result\classified\original\original_215.png -> result\classified\original\original_262.png
# 已重命名: result\classified\original\original_216.png -> result\classified\original\original_263.png
# 已重命名: result\classified\original\original_217_1.png -> result\classified\original\original_264.png
# 已重命名: result\classified\original\original_218_1.jpg -> result\classified\original\original_265.jpg
# 已重命名: result\classified\original\original_219_1_1.jpg -> result\classified\original\original_266.jpg
# 重命名文件时出错: result\classified\original\original_219_2.jpg -> result\classified\original\original_267.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\original_219_2.jpg' -> 'result\\classified\\original\\original_267.jpg'
# 已重命名: result\classified\original\original_220_1.png -> result\classified\original\original_268.png
# 已重命名: result\classified\original\original_221.jpg -> result\classified\original\original_269.jpg
# 已重命名: result\classified\original\original_222_1.jpg -> result\classified\original\original_270.jpg
# 已重命名: result\classified\original\original_223.png -> result\classified\original\original_271.png
# 已重命名: result\classified\original\original_224_1.jpg -> result\classified\original\original_272.jpg
# 已重命名: result\classified\original\original_225_1.jpg -> result\classified\original\original_273.jpg
# 已重命名: result\classified\original\original_226_1.jpg -> result\classified\original\original_274.jpg
# 已重命名: result\classified\original\original_228.jpg -> result\classified\original\original_275.jpg
# 已重命名: result\classified\original\original_228_1.png -> result\classified\original\original_276.png
# 已重命名: result\classified\original\original_229_1.jpg -> result\classified\original\original_277.jpg
# 重命名文件时出错: result\classified\original\original_22_1.jpg -> result\classified\original\original_278.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\original_22_1.jpg' -> 'result\\classified\\original\\original_278.jpg'
# 已重命名: result\classified\original\original_23.jpg -> result\classified\original\original_279.jpg
# 已重命名: result\classified\original\original_230_1.png -> result\classified\original\original_280.png
# 已重命名: result\classified\original\original_231.jpg -> result\classified\original\original_281.jpg
# 已重命名: result\classified\original\original_231_1.png -> result\classified\original\original_282.png
# 已重命名: result\classified\original\original_232_1.jpg -> result\classified\original\original_283.jpg
# 已重命名: result\classified\original\original_233_1.png -> result\classified\original\original_284.png
# 已重命名: result\classified\original\original_234.jpg -> result\classified\original\original_285.jpg
# 已重命名: result\classified\original\original_235_1.png -> result\classified\original\original_286.png
# 已重命名: result\classified\original\original_236_1.png -> result\classified\original\original_287.png
# 已重命名: result\classified\original\original_237_1.jpg -> result\classified\original\original_288.jpg
# 已重命名: result\classified\original\original_238_1.jpg -> result\classified\original\original_289.jpg
# 已重命名: result\classified\original\original_239_1.png -> result\classified\original\original_290.png
# 已重命名: result\classified\original\original_24.jpg -> result\classified\original\original_291.jpg
# 已重命名: result\classified\original\original_240_1.jpg -> result\classified\original\original_292.jpg
# 已重命名: result\classified\original\original_241_1.png -> result\classified\original\original_293.png
# 已重命名: result\classified\original\original_242_1.png -> result\classified\original\original_294.png
# 已重命名: result\classified\original\original_243_1.png -> result\classified\original\original_295.png
# 已重命名: result\classified\original\original_244_1.png -> result\classified\original\original_296.png
# 已重命名: result\classified\original\original_245.png -> result\classified\original\original_297.png
# 已重命名: result\classified\original\original_246_1.jpg -> result\classified\original\original_298.jpg
# 已重命名: result\classified\original\original_247_1.png -> result\classified\original\original_299.png
# 重命名文件时出错: result\classified\original\original_248_1.jpg -> result\classified\original\original_300.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\original_248_1.jpg' -> 'result\\classified\\original\\original_300.jpg'
# 已重命名: result\classified\original\original_249_1.jpg -> result\classified\original\original_301.jpg
# 已重命名: result\classified\original\original_250.jpg -> result\classified\original\original_302.jpg
# 已重命名: result\classified\original\original_251.jpg -> result\classified\original\original_303.jpg
# 已重命名: result\classified\original\original_251_1.png -> result\classified\original\original_304.png
# 已重命名: result\classified\original\original_252.jpg -> result\classified\original\original_305.jpg
# 已重命名: result\classified\original\original_252_1.png -> result\classified\original\original_306.png
# 已重命名: result\classified\original\original_253_1.png -> result\classified\original\original_307.png
# 已重命名: result\classified\original\original_254_1.png -> result\classified\original\original_308.png
# 已重命名: result\classified\original\original_255.jpg -> result\classified\original\original_309.jpg
# 已重命名: result\classified\original\original_256.jpg -> result\classified\original\original_310.jpg
# 重命名文件时出错: result\classified\original\original_257_1.jpg -> result\classified\original\original_311.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\original_257_1.jpg' -> 'result\\classified\\original\\original_311.jpg'
# 已重命名: result\classified\original\original_258_1.png -> result\classified\original\original_312.png
# 已重命名: result\classified\original\original_259_1.jpg -> result\classified\original\original_313.jpg
# 已重命名: result\classified\original\original_26.jpg -> result\classified\original\original_314.jpg
# 已重命名: result\classified\original\original_260_1_1.jpg -> result\classified\original\original_315.jpg
# 已重命名: result\classified\original\original_260_2.jpg -> result\classified\original\original_316.jpg
# 已重命名: result\classified\original\original_261_1.png -> result\classified\original\original_317.png
# 已重命名: result\classified\original\original_262_1.jpg -> result\classified\original\original_318.jpg
# 已重命名: result\classified\original\original_263_1.jpg -> result\classified\original\original_319.jpg
# 已重命名: result\classified\original\original_266_1.png -> result\classified\original\original_320.png
# 已重命名: result\classified\original\original_267.jpg -> result\classified\original\original_321.jpg
# 重命名文件时出错: result\classified\original\original_268.jpg -> result\classified\original\original_322.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\original\\original_268.jpg' -> 'result\\classified\\original\\original_322.jpg'
# 已重命名: result\classified\original\original_269_1.jpg -> result\classified\original\original_323.jpg
# 已重命名: result\classified\original\original_270_1.jpg -> result\classified\original\original_324.jpg
# 已重命名: result\classified\original\original_271_1.png -> result\classified\original\original_325.png
# 已重命名: result\classified\original\original_272_1.jpg -> result\classified\original\original_326.jpg
# ...
# 已重命名: result\classified\sum_2560\sum_2560_182.png -> result\classified\sum_2560\sum_2560_124.png
# 已重命名: result\classified\sum_2560\sum_2560_183.jpg -> result\classified\sum_2560\sum_2560_125.jpg
# 重命名文件时出错: result\classified\sum_2560\sum_2560_184.jpg -> result\classified\sum_2560\sum_2560_126.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\sum_2560\\sum_2560_184.jpg' -> 'result\\classified\\sum_2560\\sum_2560_126.jpg'
# 已重命名: result\classified\sum_2560\sum_2560_184.png -> result\classified\sum_2560\sum_2560_127.png
# 已重命名: result\classified\sum_2560\sum_2560_185.png -> result\classified\sum_2560\sum_2560_128.png
# 已重命名: result\classified\sum_2560\sum_2560_186.png -> result\classified\sum_2560\sum_2560_129.png
# 已重命名: result\classified\sum_2560\sum_2560_187.jpg -> result\classified\sum_2560\sum_2560_130.jpg
# 已重命名: result\classified\sum_2560\sum_2560_188.jpg -> result\classified\sum_2560\sum_2560_131.jpg
# 已重命名: result\classified\sum_2560\sum_2560_188.png -> result\classified\sum_2560\sum_2560_132.png
# 已重命名: result\classified\sum_2560\sum_2560_189.jpg -> result\classified\sum_2560\sum_2560_133.jpg
# 已重命名: result\classified\sum_2560\sum_2560_190.png -> result\classified\sum_2560\sum_2560_134.png
# 已重命名: result\classified\sum_2560\sum_2560_191.png -> result\classified\sum_2560\sum_2560_135.png
# 已重命名: result\classified\sum_2560\sum_2560_192.jpg -> result\classified\sum_2560\sum_2560_136.jpg
# 已重命名: result\classified\sum_2560\sum_2560_193.png -> result\classified\sum_2560\sum_2560_137.png
# 已重命名: result\classified\sum_2560\sum_2560_194.jpg -> result\classified\sum_2560\sum_2560_138.jpg
# 已重命名: result\classified\sum_2560\sum_2560_194.png -> result\classified\sum_2560\sum_2560_139.png
# 重命名文件时出错: result\classified\sum_2560\sum_2560_195.jpg -> result\classified\sum_2560\sum_2560_140.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\sum_2560\\sum_2560_195.jpg' -> 'result\\classified\\sum_2560\\sum_2560_140.jpg'
# 已重命名: result\classified\sum_2560\sum_2560_196.jpg -> result\classified\sum_2560\sum_2560_141.jpg
# 已重命名: result\classified\sum_2560\sum_2560_197.jpg -> result\classified\sum_2560\sum_2560_142.jpg
# 已重命名: result\classified\sum_2560\sum_2560_197.png -> result\classified\sum_2560\sum_2560_143.png
# 已重命名: result\classified\sum_2560\sum_2560_198.jpg -> result\classified\sum_2560\sum_2560_144.jpg
# 已重命名: result\classified\sum_2560\sum_2560_199.jpg -> result\classified\sum_2560\sum_2560_145.jpg
# 已重命名: result\classified\sum_2560\sum_2560_2.png -> result\classified\sum_2560\sum_2560_146.png
# 已重命名: result\classified\sum_2560\sum_2560_200.jpg -> result\classified\sum_2560\sum_2560_147.jpg
# 已重命名: result\classified\sum_2560\sum_2560_201.png -> result\classified\sum_2560\sum_2560_148.png
# 重命名文件时出错: result\classified\sum_2560\sum_2560_202.jpg -> result\classified\sum_2560\sum_2560_149.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\sum_2560\\sum_2560_202.jpg' -> 'result\\classified\\sum_2560\\sum_2560_149.jpg'
# 已重命名: result\classified\sum_2560\sum_2560_203.jpg -> result\classified\sum_2560\sum_2560_150.jpg
# 已重命名: result\classified\sum_2560\sum_2560_204.png -> result\classified\sum_2560\sum_2560_151.png
# 已重命名: result\classified\sum_2560\sum_2560_205.jpg -> result\classified\sum_2560\sum_2560_152.jpg
# 已重命名: result\classified\sum_2560\sum_2560_206.jpg -> result\classified\sum_2560\sum_2560_153.jpg
# 重命名文件时出错: result\classified\sum_2560\sum_2560_207.jpg -> result\classified\sum_2560\sum_2560_154.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\sum_2560\\sum_2560_207.jpg' -> 'result\\classified\\sum_2560\\sum_2560_154.jpg'
# 已重命名: result\classified\sum_2560\sum_2560_208.jpg -> result\classified\sum_2560\sum_2560_155.jpg
# 已重命名: result\classified\sum_2560\sum_2560_209.jpg -> result\classified\sum_2560\sum_2560_156.jpg
# 已重命名: result\classified\sum_2560\sum_2560_21.jpg -> result\classified\sum_2560\sum_2560_157.jpg
# 已重命名: result\classified\sum_2560\sum_2560_210.png -> result\classified\sum_2560\sum_2560_158.png
# 已重命名: result\classified\sum_2560\sum_2560_211.png -> result\classified\sum_2560\sum_2560_159.png
# 重命名文件时出错: result\classified\sum_2560\sum_2560_212.jpg -> result\classified\sum_2560\sum_2560_160.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\sum_2560\\sum_2560_212.jpg' -> 'result\\classified\\sum_2560\\sum_2560_160.jpg'
# 已重命名: result\classified\sum_2560\sum_2560_213.jpg -> result\classified\sum_2560\sum_2560_161.jpg
# 已重命名: result\classified\sum_2560\sum_2560_213.png -> result\classified\sum_2560\sum_2560_162.png
# 重命名文件时出错: result\classified\sum_2560\sum_2560_214.jpg -> result\classified\sum_2560\sum_2560_163.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\sum_2560\\sum_2560_214.jpg' -> 'result\\classified\\sum_2560\\sum_2560_163.jpg'
# 已重命名: result\classified\sum_2560\sum_2560_215.png -> result\classified\sum_2560\sum_2560_164.png
# 已重命名: result\classified\sum_2560\sum_2560_216.jpg -> result\classified\sum_2560\sum_2560_165.jpg
# 已重命名: result\classified\sum_2560\sum_2560_217.jpg -> result\classified\sum_2560\sum_2560_166.jpg
# 重命名文件时出错: result\classified\sum_2560\sum_2560_218.jpg -> result\classified\sum_2560\sum_2560_167.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\sum_2560\\sum_2560_218.jpg' -> 'result\\classified\\sum_2560\\sum_2560_167.jpg'
# 已重命名: result\classified\sum_2560\sum_2560_219.jpg -> result\classified\sum_2560\sum_2560_168.jpg
# 重命名文件时出错: result\classified\sum_2560\sum_2560_220.jpg -> result\classified\sum_2560\sum_2560_169.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\sum_2560\\sum_2560_220.jpg' -> 'result\\classified\\sum_2560\\sum_2560_169.jpg'
# 重命名文件时出错: result\classified\sum_2560\sum_2560_221.jpg -> result\classified\sum_2560\sum_2560_170.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\sum_2560\\sum_2560_221.jpg' -> 'result\\classified\\sum_2560\\sum_2560_170.jpg'
# 已重命名: result\classified\sum_2560\sum_2560_222.jpg -> result\classified\sum_2560\sum_2560_171.jpg
# 已重命名: result\classified\sum_2560\sum_2560_223.png -> result\classified\sum_2560\sum_2560_172.png
# 已重命名: result\classified\sum_2560\sum_2560_224.jpg -> result\classified\sum_2560\sum_2560_173.jpg
# 已重命名: result\classified\sum_2560\sum_2560_225.jpg -> result\classified\sum_2560\sum_2560_174.jpg
# 已重命名: result\classified\sum_2560\sum_2560_225.png -> result\classified\sum_2560\sum_2560_175.png
# 重命名文件时出错: result\classified\sum_2560\sum_2560_226.jpg -> result\classified\sum_2560\sum_2560_176.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\sum_2560\\sum_2560_226.jpg' -> 'result\\classified\\sum_2560\\sum_2560_176.jpg'
# 重命名文件时出错: result\classified\sum_2560\sum_2560_227.jpg -> result\classified\sum_2560\sum_2560_177.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\sum_2560\\sum_2560_227.jpg' -> 'result\\classified\\sum_2560\\sum_2560_177.jpg'
# 已重命名: result\classified\sum_2560\sum_2560_227.png -> result\classified\sum_2560\sum_2560_178.png
# 重命名文件时出错: result\classified\sum_2560\sum_2560_228.jpg -> result\classified\sum_2560\sum_2560_179.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\sum_2560\\sum_2560_228.jpg' -> 'result\\classified\\sum_2560\\sum_2560_179.jpg'
# 重命名文件时出错: result\classified\sum_2560\sum_2560_229.jpg -> result\classified\sum_2560\sum_2560_180.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\sum_2560\\sum_2560_229.jpg' -> 'result\\classified\\sum_2560\\sum_2560_180.jpg'
# 已重命名: result\classified\sum_2560\sum_2560_230.jpg -> result\classified\sum_2560\sum_2560_181.jpg
# 已重命名: result\classified\sum_2560\sum_2560_230.png -> result\classified\sum_2560\sum_2560_182.png
# 已重命名: result\classified\sum_2560\sum_2560_231.jpg -> result\classified\sum_2560\sum_2560_183.jpg
# 重命名文件时出错: result\classified\sum_2560\sum_2560_232.jpg -> result\classified\sum_2560\sum_2560_184.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\sum_2560\\sum_2560_232.jpg' -> 'result\\classified\\sum_2560\\sum_2560_184.jpg'
# 已重命名: result\classified\sum_2560\sum_2560_233.png -> result\classified\sum_2560\sum_2560_185.png
# 已重命名: result\classified\sum_2560\sum_2560_234.jpg -> result\classified\sum_2560\sum_2560_186.jpg
# 已重命名: result\classified\sum_2560\sum_2560_235.jpg -> result\classified\sum_2560\sum_2560_187.jpg
# 已重命名: result\classified\sum_2560\sum_2560_236.jpg -> result\classified\sum_2560\sum_2560_188.jpg
# 已重命名: result\classified\sum_2560\sum_2560_237.jpg -> result\classified\sum_2560\sum_2560_189.jpg
# 已重命名: result\classified\sum_2560\sum_2560_238.jpg -> result\classified\sum_2560\sum_2560_190.jpg
# 已重命名: result\classified\sum_2560\sum_2560_239.jpg -> result\classified\sum_2560\sum_2560_191.jpg
# 已重命名: result\classified\sum_2560\sum_2560_240.jpg -> result\classified\sum_2560\sum_2560_192.jpg
# 已重命名: result\classified\sum_2560\sum_2560_241.jpg -> result\classified\sum_2560\sum_2560_193.jpg
# 已重命名: result\classified\sum_2560\sum_2560_242.jpg -> result\classified\sum_2560\sum_2560_194.jpg
# 重命名文件时出错: result\classified\sum_2560\sum_2560_243.jpg -> result\classified\sum_2560\sum_2560_195.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\sum_2560\\sum_2560_243.jpg' -> 'result\\classified\\sum_2560\\sum_2560_195.jpg'
# 已重命名: result\classified\sum_2560\sum_2560_244.png -> result\classified\sum_2560\sum_2560_196.png
# 已重命名: result\classified\sum_2560\sum_2560_245.png -> result\classified\sum_2560\sum_2560_197.png
# 已重命名: result\classified\sum_2560\sum_2560_246.jpg -> result\classified\sum_2560\sum_2560_198.jpg
# 已重命名: result\classified\sum_2560\sum_2560_247.jpg -> result\classified\sum_2560\sum_2560_199.jpg
# 已重命名: result\classified\sum_2560\sum_2560_25.jpg -> result\classified\sum_2560\sum_2560_200.jpg
# 已重命名: result\classified\sum_2560\sum_2560_26.jpg -> result\classified\sum_2560\sum_2560_201.jpg
# 重命名文件时出错: result\classified\sum_2560\sum_2560_27.jpg -> result\classified\sum_2560\sum_2560_202.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\sum_2560\\sum_2560_27.jpg' -> 'result\\classified\\sum_2560\\sum_2560_202.jpg'
# 已重命名: result\classified\sum_2560\sum_2560_28.png -> result\classified\sum_2560\sum_2560_203.png
# 已重命名: result\classified\sum_2560\sum_2560_29.jpg -> result\classified\sum_2560\sum_2560_204.jpg
# 已重命名: result\classified\sum_2560\sum_2560_3.jpg -> result\classified\sum_2560\sum_2560_205.jpg
# 已重命名: result\classified\sum_2560\sum_2560_30.jpg -> result\classified\sum_2560\sum_2560_206.jpg
# 重命名文件时出错: result\classified\sum_2560\sum_2560_32.jpg -> result\classified\sum_2560\sum_2560_207.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\sum_2560\\sum_2560_32.jpg' -> 'result\\classified\\sum_2560\\sum_2560_207.jpg'
# 已重命名: result\classified\sum_2560\sum_2560_36.jpg -> result\classified\sum_2560\sum_2560_208.jpg
# 已重命名: result\classified\sum_2560\sum_2560_37.jpg -> result\classified\sum_2560\sum_2560_209.jpg
# 已重命名: result\classified\sum_2560\sum_2560_38.jpg -> result\classified\sum_2560\sum_2560_210.jpg
# 已重命名: result\classified\sum_2560\sum_2560_39.jpg -> result\classified\sum_2560\sum_2560_211.jpg
# 重命名文件时出错: result\classified\sum_2560\sum_2560_40.jpg -> result\classified\sum_2560\sum_2560_212.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\sum_2560\\sum_2560_40.jpg' -> 'result\\classified\\sum_2560\\sum_2560_212.jpg'
# 已重命名: result\classified\sum_2560\sum_2560_41.jpg -> result\classified\sum_2560\sum_2560_213.jpg
# 重命名文件时出错: result\classified\sum_2560\sum_2560_42.jpg -> result\classified\sum_2560\sum_2560_214.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\sum_2560\\sum_2560_42.jpg' -> 'result\\classified\\sum_2560\\sum_2560_214.jpg'
# 已重命名: result\classified\sum_2560\sum_2560_44.jpg -> result\classified\sum_2560\sum_2560_215.jpg
# 已重命名: result\classified\sum_2560\sum_2560_45.jpg -> result\classified\sum_2560\sum_2560_216.jpg
# 已重命名: result\classified\sum_2560\sum_2560_46.jpg -> result\classified\sum_2560\sum_2560_217.jpg
# 重命名文件时出错: result\classified\sum_2560\sum_2560_47.jpg -> result\classified\sum_2560\sum_2560_218.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\sum_2560\\sum_2560_47.jpg' -> 'result\\classified\\sum_2560\\sum_2560_218.jpg'
# 已重命名: result\classified\sum_2560\sum_2560_49.png -> result\classified\sum_2560\sum_2560_219.png
# 重命名文件时出错: result\classified\sum_2560\sum_2560_5.jpg -> result\classified\sum_2560\sum_2560_220.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\sum_2560\\sum_2560_5.jpg' -> 'result\\classified\\sum_2560\\sum_2560_220.jpg'
# 重命名文件时出错: result\classified\sum_2560\sum_2560_53.jpg -> result\classified\sum_2560\sum_2560_221.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\sum_2560\\sum_2560_53.jpg' -> 'result\\classified\\sum_2560\\sum_2560_221.jpg'
# 已重命名: result\classified\sum_2560\sum_2560_57.jpg -> result\classified\sum_2560\sum_2560_222.jpg
# 已重命名: result\classified\sum_2560\sum_2560_6.jpg -> result\classified\sum_2560\sum_2560_223.jpg
# 已重命名: result\classified\sum_2560\sum_2560_6.png -> result\classified\sum_2560\sum_2560_224.png
# 已重命名: result\classified\sum_2560\sum_2560_61.png -> result\classified\sum_2560\sum_2560_225.png
# 重命名文件时出错: result\classified\sum_2560\sum_2560_62.jpg -> result\classified\sum_2560\sum_2560_226.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\sum_2560\\sum_2560_62.jpg' -> 'result\\classified\\sum_2560\\sum_2560_226.jpg'
# 重命名文件时出错: result\classified\sum_2560\sum_2560_65.jpg -> result\classified\sum_2560\sum_2560_227.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\sum_2560\\sum_2560_65.jpg' -> 'result\\classified\\sum_2560\\sum_2560_227.jpg'
# 重命名文件时出错: result\classified\sum_2560\sum_2560_66.jpg -> result\classified\sum_2560\sum_2560_228.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\sum_2560\\sum_2560_66.jpg' -> 'result\\classified\\sum_2560\\sum_2560_228.jpg'
# 已重命名: result\classified\sum_2560\sum_2560_68.png -> result\classified\sum_2560\sum_2560_229.png
# 已重命名: result\classified\sum_2560\sum_2560_7.jpg -> result\classified\sum_2560\sum_2560_230.jpg
# 已重命名: result\classified\sum_2560\sum_2560_70.png -> result\classified\sum_2560\sum_2560_231.png
# 重命名文件时出错: result\classified\sum_2560\sum_2560_71.jpg -> result\classified\sum_2560\sum_2560_232.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\sum_2560\\sum_2560_71.jpg' -> 'result\\classified\\sum_2560\\sum_2560_232.jpg'
# 已重命名: result\classified\sum_2560\sum_2560_74.png -> result\classified\sum_2560\sum_2560_233.png
# 已重命名: result\classified\sum_2560\sum_2560_76.jpg -> result\classified\sum_2560\sum_2560_234.jpg
# 已重命名: result\classified\sum_2560\sum_2560_77.jpg -> result\classified\sum_2560\sum_2560_235.jpg
# 已重命名: result\classified\sum_2560\sum_2560_78.png -> result\classified\sum_2560\sum_2560_236.png
# 已重命名: result\classified\sum_2560\sum_2560_79.png -> result\classified\sum_2560\sum_2560_237.png
# 已重命名: result\classified\sum_2560\sum_2560_82.jpg -> result\classified\sum_2560\sum_2560_238.jpg
# 已重命名: result\classified\sum_2560\sum_2560_84.jpg -> result\classified\sum_2560\sum_2560_239.jpg
# 已重命名: result\classified\sum_2560\sum_2560_86.jpg -> result\classified\sum_2560\sum_2560_240.jpg
# 已重命名: result\classified\sum_2560\sum_2560_9.jpg -> result\classified\sum_2560\sum_2560_241.jpg
# 已重命名: result\classified\sum_2560\sum_2560_90.jpg -> result\classified\sum_2560\sum_2560_242.jpg
# 重命名文件时出错: result\classified\sum_2560\sum_2560_91.jpg -> result\classified\sum_2560\sum_2560_243.jpg - [WinError 183] 当文件已存在时，无法创建该文件。: 'result\\classified\\sum_2560\\sum_2560_91.jpg' -> 'result\\classified\\sum_2560\\sum_2560_243.jpg'
# 已重命名: result\classified\sum_2560\sum_2560_94.jpg -> result\classified\sum_2560\sum_2560_244.jpg
# 已重命名: result\classified\sum_2560\sum_2560_96.jpg -> result\classified\sum_2560\sum_2560_245.jpg
# 已重命名: result\classified\sum_2560\sum_2560_97.jpg -> result\classified\sum_2560\sum_2560_246.jpg
# 已重命名: result\classified\sum_2560\sum_2560_98.jpg -> result\classified\sum_2560\sum_2560_247.jpg
# 已删除空目录: result\classified\sum_1923
# 已删除空目录: result\classified\sum_2018
# 已删除空目录: result\classified\sum_2084
# 已删除空目录: result\classified\sum_2240
# 已删除空目录: result\classified\sum_2304

# %%
from PIL import Image
import os

def crop_images_to_min_dimensions(folder_path, output_folder):
    # 获取文件夹中所有图片文件
    files = [f for f in os.listdir(folder_path) if f.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif'))]
    
    if not files:
        print("文件夹中没有找到图片文件！")
        return

    # 找到最小的宽度和高度
    min_width = float('inf')
    min_height = float('inf')
    for file in files:
        img_path = os.path.join(folder_path, file)
        with Image.open(img_path) as img:
            width, height = img.size
            if width < min_width:
                min_width = width
            if height < min_height:
                min_height = height

    print(f"最小宽度为：{min_width}")
    print(f"最小高度为：{min_height}")

    # 创建输出文件夹
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # 裁剪所有图片
    for file in files:
        img_path = os.path.join(folder_path, file)
        with Image.open(img_path) as img:
            width, height = img.size
            # 计算裁剪的边界
            left = (width - min_width) // 2
            top = (height - min_height) // 2
            right = left + min_width
            bottom = top + min_height

            # 裁剪图片
            cropped_img = img.crop((left, top, right, bottom))

            # 如果图片是 RGBA 模式，转换为 RGB 模式
            if cropped_img.mode == 'RGBA':
                cropped_img = cropped_img.convert('RGB')

            output_path = os.path.join(output_folder, file)
            cropped_img.save(output_path)

        print(f"已裁剪并保存：{file}")

    print("所有图片裁剪完成！")

# 使用示例
folder_path = "result/剪映媒体"  # 替换为你的图片文件夹路径
output_folder = "result/剪映媒体/output"

crop_images_to_min_dimensions(folder_path, output_folder)
# Out:
# 最小宽度为：1280
# 最小高度为：1280
# 已裁剪并保存：sum_2560_1.jpg
# 已裁剪并保存：sum_2560_10.png
# 已裁剪并保存：sum_2560_100.jpg
# 已裁剪并保存：sum_2560_101.jpg
# 已裁剪并保存：sum_2560_102.jpg
# 已裁剪并保存：sum_2560_102.png
# 已裁剪并保存：sum_2560_103.jpg
# 已裁剪并保存：sum_2560_104.png
# 已裁剪并保存：sum_2560_105.jpg
# 已裁剪并保存：sum_2560_105.png
# 已裁剪并保存：sum_2560_106.jpg
# 已裁剪并保存：sum_2560_107.jpg
# 已裁剪并保存：sum_2560_108.jpg
# 已裁剪并保存：sum_2560_108.png
# 已裁剪并保存：sum_2560_109.jpg
# 已裁剪并保存：sum_2560_109.png
# 已裁剪并保存：sum_2560_110.jpg
# 已裁剪并保存：sum_2560_111.png
# 已裁剪并保存：sum_2560_112.jpg
# 已裁剪并保存：sum_2560_113.jpg
# 已裁剪并保存：sum_2560_114.png
# 已裁剪并保存：sum_2560_115.jpg
# 已裁剪并保存：sum_2560_116.jpg
# 已裁剪并保存：sum_2560_116.png
# 已裁剪并保存：sum_2560_117.jpg
# 已裁剪并保存：sum_2560_117.png
# 已裁剪并保存：sum_2560_118.jpg
# 已裁剪并保存：sum_2560_119.jpg
# 已裁剪并保存：sum_2560_12.png
# 已裁剪并保存：sum_2560_120.jpg
# 已裁剪并保存：sum_2560_121.jpg
# 已裁剪并保存：sum_2560_122.jpg
# 已裁剪并保存：sum_2560_123.jpg
# 已裁剪并保存：sum_2560_124.jpg
# 已裁剪并保存：sum_2560_124.png
# 已裁剪并保存：sum_2560_125.jpg
# 已裁剪并保存：sum_2560_126.jpg
# 已裁剪并保存：sum_2560_127.jpg
# 已裁剪并保存：sum_2560_127.png
# 已裁剪并保存：sum_2560_128.png
# 已裁剪并保存：sum_2560_129.jpg
# 已裁剪并保存：sum_2560_129.png
# 已裁剪并保存：sum_2560_13.png
# 已裁剪并保存：sum_2560_130.jpg
# 已裁剪并保存：sum_2560_131.jpg
# 已裁剪并保存：sum_2560_132.png
# 已裁剪并保存：sum_2560_133.jpg
# 已裁剪并保存：sum_2560_134.jpg
# 已裁剪并保存：sum_2560_134.png
# 已裁剪并保存：sum_2560_135.png
# 已裁剪并保存：sum_2560_136.jpg
# 已裁剪并保存：sum_2560_137.png
# 已裁剪并保存：sum_2560_138.jpg
# 已裁剪并保存：sum_2560_139.png
# 已裁剪并保存：sum_2560_14.jpg
# 已裁剪并保存：sum_2560_140.jpg
# 已裁剪并保存：sum_2560_141.jpg
# 已裁剪并保存：sum_2560_142.jpg
# 已裁剪并保存：sum_2560_143.png
# 已裁剪并保存：sum_2560_144.jpg
# 已裁剪并保存：sum_2560_145.jpg
# 已裁剪并保存：sum_2560_146.png
# 已裁剪并保存：sum_2560_147.jpg
# 已裁剪并保存：sum_2560_148.png
# 已裁剪并保存：sum_2560_149.jpg
# 已裁剪并保存：sum_2560_15.jpg
# 已裁剪并保存：sum_2560_15.png
# 已裁剪并保存：sum_2560_150.jpg
# 已裁剪并保存：sum_2560_151.png
# 已裁剪并保存：sum_2560_152.jpg
# 已裁剪并保存：sum_2560_153.jpg
# 已裁剪并保存：sum_2560_154.jpg
# 已裁剪并保存：sum_2560_155.jpg
# 已裁剪并保存：sum_2560_156.jpg
# 已裁剪并保存：sum_2560_157.jpg
# 已裁剪并保存：sum_2560_158.jpg
# 已裁剪并保存：sum_2560_158.png
# 已裁剪并保存：sum_2560_159.jpg
# 已裁剪并保存：sum_2560_159.png
# 已裁剪并保存：sum_2560_16.png
# 已裁剪并保存：sum_2560_160.jpg
# 已裁剪并保存：sum_2560_161.jpg
# 已裁剪并保存：sum_2560_162.jpg
# 已裁剪并保存：sum_2560_162.png
# 已裁剪并保存：sum_2560_163.jpg
# 已裁剪并保存：sum_2560_164.jpg
# 已裁剪并保存：sum_2560_164.png
# 已裁剪并保存：sum_2560_165.jpg
# 已裁剪并保存：sum_2560_166.jpg
# 已裁剪并保存：sum_2560_167.jpg
# 已裁剪并保存：sum_2560_168.jpg
# 已裁剪并保存：sum_2560_169.jpg
# 已裁剪并保存：sum_2560_17.jpg
# 已裁剪并保存：sum_2560_170.jpg
# 已裁剪并保存：sum_2560_171.jpg
# 已裁剪并保存：sum_2560_172.png
# 已裁剪并保存：sum_2560_173.jpg
# 已裁剪并保存：sum_2560_174.jpg
# 已裁剪并保存：sum_2560_175.jpg
# 已裁剪并保存：sum_2560_175.png
# 已裁剪并保存：sum_2560_176.jpg
# 已裁剪并保存：sum_2560_177.jpg
# 已裁剪并保存：sum_2560_178.png
# 已裁剪并保存：sum_2560_179.jpg
# 已裁剪并保存：sum_2560_18.png
# 已裁剪并保存：sum_2560_180.jpg
# 已裁剪并保存：sum_2560_181.jpg
# 已裁剪并保存：sum_2560_182.png
# 已裁剪并保存：sum_2560_183.jpg
# 已裁剪并保存：sum_2560_184.jpg
# 已裁剪并保存：sum_2560_185.png
# 已裁剪并保存：sum_2560_186.jpg
# 已裁剪并保存：sum_2560_187.jpg
# 已裁剪并保存：sum_2560_188.jpg
# 已裁剪并保存：sum_2560_189.jpg
# 已裁剪并保存：sum_2560_19.jpg
# 已裁剪并保存：sum_2560_190.jpg
# 已裁剪并保存：sum_2560_191.jpg
# 已裁剪并保存：sum_2560_192.jpg
# 已裁剪并保存：sum_2560_193.jpg
# 已裁剪并保存：sum_2560_194.jpg
# 已裁剪并保存：sum_2560_195.jpg
# 已裁剪并保存：sum_2560_196.png
# 已裁剪并保存：sum_2560_197.png
# 已裁剪并保存：sum_2560_198.jpg
# 已裁剪并保存：sum_2560_199.jpg
# 已裁剪并保存：sum_2560_20.jpg
# 已裁剪并保存：sum_2560_200.jpg
# 已裁剪并保存：sum_2560_201.jpg
# 已裁剪并保存：sum_2560_202.jpg
# 已裁剪并保存：sum_2560_203.png
# 已裁剪并保存：sum_2560_204.jpg
# 已裁剪并保存：sum_2560_205.jpg
# 已裁剪并保存：sum_2560_206.jpg
# 已裁剪并保存：sum_2560_207.jpg
# 已裁剪并保存：sum_2560_208.jpg
# 已裁剪并保存：sum_2560_209.jpg
# 已裁剪并保存：sum_2560_210.jpg
# 已裁剪并保存：sum_2560_211.jpg
# 已裁剪并保存：sum_2560_212.jpg
# 已裁剪并保存：sum_2560_213.jpg
# 已裁剪并保存：sum_2560_214.jpg
# 已裁剪并保存：sum_2560_215.jpg
# 已裁剪并保存：sum_2560_216.jpg
# 已裁剪并保存：sum_2560_217.jpg
# 已裁剪并保存：sum_2560_218.jpg
# 已裁剪并保存：sum_2560_219.png
# 已裁剪并保存：sum_2560_22.png
# 已裁剪并保存：sum_2560_220.jpg
# 已裁剪并保存：sum_2560_221.jpg
# 已裁剪并保存：sum_2560_222.jpg
# 已裁剪并保存：sum_2560_223.jpg
# 已裁剪并保存：sum_2560_224.png
# 已裁剪并保存：sum_2560_225.png
# 已裁剪并保存：sum_2560_226.jpg
# 已裁剪并保存：sum_2560_227.jpg
# 已裁剪并保存：sum_2560_228.jpg
# 已裁剪并保存：sum_2560_229.jpg
# 已裁剪并保存：sum_2560_229.png
# 已裁剪并保存：sum_2560_23.jpg
# 已裁剪并保存：sum_2560_230.jpg
# 已裁剪并保存：sum_2560_231.png
# 已裁剪并保存：sum_2560_232.jpg
# 已裁剪并保存：sum_2560_233.png
# 已裁剪并保存：sum_2560_234.jpg
# 已裁剪并保存：sum_2560_235.jpg
# 已裁剪并保存：sum_2560_236.png
# 已裁剪并保存：sum_2560_237.png
# 已裁剪并保存：sum_2560_238.jpg
# 已裁剪并保存：sum_2560_239.jpg
# 已裁剪并保存：sum_2560_24.png
# 已裁剪并保存：sum_2560_240.jpg
# 已裁剪并保存：sum_2560_241.jpg
# 已裁剪并保存：sum_2560_242.jpg
# 已裁剪并保存：sum_2560_243.jpg
# 已裁剪并保存：sum_2560_244.jpg
# 已裁剪并保存：sum_2560_245.jpg
# 已裁剪并保存：sum_2560_246.jpg
# 已裁剪并保存：sum_2560_247.jpg
# 已裁剪并保存：sum_2560_26.png
# 已裁剪并保存：sum_2560_27.jpg
# 已裁剪并保存：sum_2560_30.png
# 已裁剪并保存：sum_2560_31.png
# 已裁剪并保存：sum_2560_32.jpg
# 已裁剪并保存：sum_2560_33.png
# 已裁剪并保存：sum_2560_34.jpg
# 已裁剪并保存：sum_2560_35.jpg
# 已裁剪并保存：sum_2560_36.png
# 已裁剪并保存：sum_2560_38.png
# 已裁剪并保存：sum_2560_39.png
# 已裁剪并保存：sum_2560_4.jpg
# 已裁剪并保存：sum_2560_40.jpg
# 已裁剪并保存：sum_2560_41.png
# 已裁剪并保存：sum_2560_42.jpg
# 已裁剪并保存：sum_2560_43.png
# 已裁剪并保存：sum_2560_45.png
# 已裁剪并保存：sum_2560_46.png
# 已裁剪并保存：sum_2560_47.jpg
# 已裁剪并保存：sum_2560_48.png
# 已裁剪并保存：sum_2560_5.jpg
# 已裁剪并保存：sum_2560_5.png
# 已裁剪并保存：sum_2560_50.jpg
# 已裁剪并保存：sum_2560_51.png
# 已裁剪并保存：sum_2560_52.jpg
# 已裁剪并保存：sum_2560_53.jpg
# 已裁剪并保存：sum_2560_53.png
# 已裁剪并保存：sum_2560_54.jpg
# 已裁剪并保存：sum_2560_55.jpg
# 已裁剪并保存：sum_2560_56.png
# 已裁剪并保存：sum_2560_58.png
# 已裁剪并保存：sum_2560_59.png
# 已裁剪并保存：sum_2560_60.jpg
# 已裁剪并保存：sum_2560_61.jpg
# 已裁剪并保存：sum_2560_62.jpg
# 已裁剪并保存：sum_2560_62.png
# 已裁剪并保存：sum_2560_63.jpg
# 已裁剪并保存：sum_2560_64.jpg
# 已裁剪并保存：sum_2560_65.jpg
# 已裁剪并保存：sum_2560_66.jpg
# 已裁剪并保存：sum_2560_67.png
# 已裁剪并保存：sum_2560_68.jpg
# 已裁剪并保存：sum_2560_69.png
# 已裁剪并保存：sum_2560_70.jpg
# 已裁剪并保存：sum_2560_71.jpg
# 已裁剪并保存：sum_2560_71.png
# 已裁剪并保存：sum_2560_72.jpg
# 已裁剪并保存：sum_2560_73.jpg
# 已裁剪并保存：sum_2560_74.jpg
# 已裁剪并保存：sum_2560_75.jpg
# 已裁剪并保存：sum_2560_77.png
# 已裁剪并保存：sum_2560_79.jpg
# 已裁剪并保存：sum_2560_8.png
# 已裁剪并保存：sum_2560_80.png
# 已裁剪并保存：sum_2560_81.jpg
# 已裁剪并保存：sum_2560_82.png
# 已裁剪并保存：sum_2560_83.jpg
# 已裁剪并保存：sum_2560_84.png
# 已裁剪并保存：sum_2560_85.png
# 已裁剪并保存：sum_2560_87.jpg
# 已裁剪并保存：sum_2560_88.jpg
# 已裁剪并保存：sum_2560_89.jpg
# 已裁剪并保存：sum_2560_91.jpg
# 已裁剪并保存：sum_2560_92.png
# 已裁剪并保存：sum_2560_93.jpg
# 已裁剪并保存：sum_2560_95.jpg
# 已裁剪并保存：sum_2560_97.png
# 已裁剪并保存：sum_2560_99.png
# 所有图片裁剪完成！

# %%
import cv2
import numpy as np
import os
from pathlib import Path
import random
from datetime import datetime

def calculate_average_color(image_path):
    """
    计算图片的平均颜色
    """
    image = cv2.imread(image_path)
    if image is None:
        raise ValueError(f"无法读取图片：{image_path}。请检查图片路径和文件格式。")
    average_color = np.mean(image, axis=(0, 1)).astype(int)
    return average_color

def calculate_color_similarity(color1, color2):
    """
    计算两种颜色的相似度（欧几里得距离）
    """
    return np.linalg.norm(color1 - color2)

def select_images_by_color_similarity(image_paths, num_images=12, image_usage_count=None):
    """
    根据颜色相似度选择图片
    """
    if len(image_paths) < num_images:
        raise ValueError(f"图片数量不足{num_images}张，请确保文件夹中有足够的图片。")

    # 计算每张图片的平均颜色
    image_colors = {path: calculate_average_color(path) for path in image_paths}

    # 选择第一张图片作为参考
    reference_color = image_colors[random.choice(list(image_colors.keys()))]

    # 按颜色相似度排序
    sorted_images = sorted(image_colors.items(), key=lambda item: calculate_color_similarity(item[1], reference_color))

    # 选择前num_images张图片，同时检查使用次数
    selected_image_paths = []
    for path, _ in sorted_images:
        if image_usage_count[path] < 3:
            selected_image_paths.append(path)
            image_usage_count[path] += 1
        if len(selected_image_paths) == num_images:
            break

    if len(selected_image_paths) < num_images:
        raise ValueError("无法选择足够的图片，请检查图片数量和使用次数限制。")

    return selected_image_paths

def create_video_from_images(image_paths, output_video_path, total_duration=8, fps=60):
    """
    从指定的图片路径列表生成视频
    """
    # 调整图片大小并检查通道数
    processed_images, target_size = resize_and_check_images(image_paths)

    # 计算每张图片的展示时间
    total_frames = total_duration * fps  # 总帧数
    frames_per_image = total_frames // len(image_paths)  # 每张图片展示的帧数

    # 创建视频写入器
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    video_writer = cv2.VideoWriter(output_video_path, fourcc, fps, target_size)

    # 将每张图片写入视频
    for img in processed_images:
        for _ in range(frames_per_image):
            video_writer.write(img)

    video_writer.release()
    print(f"视频已成功创建: {output_video_path}")

def resize_and_check_images(image_paths):
    """
    调整图片大小并检查通道数
    使用第一张图片的大小作为目标大小
    """
    resized_images = []

    # 获取第一张图片的大小作为目标大小
    first_image_path = image_paths[0]
    first_image = cv2.imread(first_image_path)
    
    if first_image is None:
        raise ValueError(f"无法读取图片：{first_image_path}。请检查图片路径和文件格式。")

    target_size = (first_image.shape[1], first_image.shape[0])

    for path in image_paths:
        img = cv2.imread(path)
        
        if img is None:
            raise ValueError(f"无法读取图片：{path}。请检查图片路径和文件格式。")

        # 调整图片大小
        if img.shape[:2] != target_size[::-1]:
            img = cv2.resize(img, target_size)

        # 检查通道数，确保是3通道
        if len(img.shape) == 2:  # 灰度图
            img = cv2.cvtColor(img, cv2.COLOR_GRAY2BGR)
        elif img.shape[2] == 4:  # RGBA图像
            img = cv2.cvtColor(img, cv2.COLOR_BGRA2BGR)

        resized_images.append(img)

    return resized_images, target_size

if __name__ == "__main__":
    # 设置图片目录和输出目录
    image_directory = "images"  # 替换为你的图片目录
    output_directory = "output_videos"  # 输出视频文件夹

    # 创建输出目录（如果不存在）
    Path(output_directory).mkdir(parents=True, exist_ok=True)

    # 获取文件夹中所有图片文件
    image_extensions = ['.jpg', '.jpeg', '.png', '.bmp', '.webp']
    image_paths = [str(file) for file in Path(image_directory).iterdir() if file.suffix.lower() in image_extensions]

    if len(image_paths) < 12:
        raise ValueError("图片数量不足12张，请确保文件夹中有足够的图片。")

    # 确保每张图片至少出现一次，至多出现三次
    max_occurrences = 3
    image_usage_count = {path: 0 for path in image_paths}

    # 循环运行20次
    for i in range(3):
        # 使用当前时间生成输出视频文件名
        current_time = datetime.now().strftime("%Y%m%d_%H%M%S")
        output_video_path = Path(output_directory) / f"{current_time}_output_video_{i+1}.mp4"

        try:
            # 选择颜色相近的图片
            selected_image_paths = select_images_by_color_similarity(image_paths, num_images=12, image_usage_count=image_usage_count)

            # 创建视频
            create_video_from_images(selected_image_paths, str(output_video_path), total_duration=8, fps=60)

        except Exception as e:
            print(f"生成视频时发生错误: {e}")

    # 输出每张图片的使用次数
    print("每张图片的使用次数：")
    for path, count in image_usage_count.items():
        print(f"{path}: {count}次")
# Out:
# 视频已成功创建: output_videos\20250720_172531_output_video_1.mp4
# 视频已成功创建: output_videos\20250720_172536_output_video_2.mp4
# 视频已成功创建: output_videos\20250720_172541_output_video_3.mp4
# 每张图片的使用次数：
# images\sum_2560_10.png: 2次
# images\sum_2560_115.jpg: 1次
# images\sum_2560_116.jpg: 1次
# images\sum_2560_120.jpg: 1次
# images\sum_2560_125.jpg: 1次
# images\sum_2560_128.png: 2次
# images\sum_2560_129.png: 2次
# images\sum_2560_130.jpg: 1次
# images\sum_2560_14.jpg: 1次
# images\sum_2560_16.png: 1次
# images\sum_2560_172.png: 0次
# images\sum_2560_175.jpg: 0次
# images\sum_2560_175.png: 2次
# images\sum_2560_202.jpg: 2次
# images\sum_2560_207.jpg: 1次
# images\sum_2560_218.jpg: 1次
# images\sum_2560_22.png: 2次
# images\sum_2560_221.jpg: 0次
# images\sum_2560_226.jpg: 2次
# images\sum_2560_227.jpg: 1次
# images\sum_2560_235.jpg: 1次
# images\sum_2560_236.png: 2次
# images\sum_2560_36.png: 1次
# images\sum_2560_40.jpg: 1次
# images\sum_2560_41.png: 0次
# images\sum_2560_53.png: 2次
# images\sum_2560_54.jpg: 1次
# images\sum_2560_85.png: 2次
# images\sum_2560_89.jpg: 1次
# images\sum_2560_99.png: 1次

# %%
import cv2
import numpy as np
import os
from pathlib import Path
from datetime import datetime

def resize_and_check_images(image_paths, target_size=None):
    """
    调整图片大小并检查通道数
    如果target_size为None，则使用第一张图片的大小作为目标大小
    """
    resized_images = []
    
    # 获取第一张图片的大小作为目标大小
    if target_size is None:
        first_image = cv2.imread(image_paths[0])
        target_size = (first_image.shape[1], first_image.shape[0])
    
    for path in image_paths:
        img = cv2.imread(path)
        
        # 调整图片大小
        if img.shape[:2] != target_size[::-1]:
            img = cv2.resize(img, target_size)
        
        # 检查通道数，确保是3通道
        if len(img.shape) == 2:  # 灰度图
            img = cv2.cvtColor(img, cv2.COLOR_GRAY2BGR)
        elif img.shape[2] == 4:  # RGBA图像
            img = cv2.cvtColor(img, cv2.COLOR_BGRA2BGR)
        
        resized_images.append(img)
    
    return resized_images, target_size

def create_video_from_images(image_paths, output_video_path, fps=60, transition_duration=1):
    """
    将一组图片转换为视频，并添加多样化的过渡效果
    
    参数：
    image_paths: 图片文件路径列表
    output_video_path: 输出视频文件路径
    fps: 视频帧率，默认30fps
    transition_duration: 过渡效果持续时间（秒），默认1秒
    """
    
    # 调整图片大小并检查通道数
    processed_images, target_size = resize_and_check_images(image_paths)
    width, height = target_size
    
    # 创建视频写入器
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    video_writer = cv2.VideoWriter(output_video_path, fourcc, fps, (width, height))
    
    # 每张图片显示的总帧数 = 过渡帧数 + 停留帧数
    transition_frames = int(transition_duration * fps)
    display_frames = int(0.05 * transition_frames)  # 每张图片显示2秒过渡时间
    
    # 定义不同的过渡效果
    transition_styles = [
        "fade"         # 淡入淡出
        # "slide"        # 平移过渡
        # "zoom",          # 缩放过渡
        # "rotate",        # 旋转过渡
        # "checkerboard",  # 棋盘格过渡
        # "door",          # 门过渡
        # "horizontal_blinds",  # 水平百叶窗
        # "vertical_blinds",    # 垂直百叶窗
        # "dissolve",      # 溶解效果
        # "flip",          # 翻转效果
        # "roll",          # 滚动效果
        # "grid_wipe",     # 网格擦除
        # "chaos"          # 混沌效果
    ]
    
    # 处理每张图片
    for i in range(len(processed_images) - 1):
        current_image = processed_images[i]
        next_image = processed_images[i+1]
        
        # 随机选择过渡效果
        transition_style = np.random.choice(transition_styles)
        
        # 添加图片展示部分
        for _ in range(display_frames):
            video_writer.write(current_image)
        
        # 根据选择的过渡风格应用相应的过渡效果
        if transition_style == "fade":
            # 淡入淡出效果
            for j in range(transition_frames):
                alpha = j / transition_frames
                blended = cv2.addWeighted(current_image, 1 - alpha, next_image, alpha, 0)
                video_writer.write(blended)
        
        elif transition_style == "slide":
            # 平移过渡效果
            for j in range(transition_frames):
                # 从右向左滑动
                shift = int(width * (1 - j / transition_frames))
                transition_frame = np.zeros_like(current_image)
                
                # 复制当前图片到左侧
                transition_frame[:, :shift] = current_image[:, :shift]
                
                # 复制下一张图片到右侧
                next_part = next_image[:, :width - shift]
                transition_frame[:, shift:shift + next_part.shape[1]] = next_part
                
                video_writer.write(transition_frame)
        
        elif transition_style == "zoom":
            # 缩放过渡效果
            for j in range(transition_frames):
                scale = 1 + 0.3 * (1 - j / transition_frames)  # 从放大到正常大小
                zoomed_current = cv2.resize(current_image, None, fx=scale, fy=scale)
                zoomed_next = cv2.resize(next_image, None, fx=scale, fy=scale)
                
                # 裁剪图像到原始大小
                height_zoomed, width_zoomed, _ = zoomed_current.shape
                start_y = (height_zoomed - height) // 2
                start_x = (width_zoomed - width) // 2
                
                current_cropped = zoomed_current[start_y:start_y+height, start_x:start_x+width]
                next_cropped = zoomed_next[start_y:start_y+height, start_x:start_x+width]
                
                # 混合两张图片
                alpha = j / transition_frames
                blended = cv2.addWeighted(current_cropped, 1 - alpha, next_cropped, alpha, 0)
                video_writer.write(blended)
        
        elif transition_style == "rotate":
            # 旋转过渡效果
            for j in range(transition_frames):
                angle = 30 * (1 - j / transition_frames)  # 从30度旋转到0度
                scale = 1
                
                # 旋转当前图片
                M = cv2.getRotationMatrix2D((width//2, height//2), angle, scale)
                rotated_current = cv2.warpAffine(current_image, M, (width, height))
                
                # 旋转下一张图片（反方向）
                M = cv2.getRotationMatrix2D((width//2, height//2), -angle, scale)
                rotated_next = cv2.warpAffine(next_image, M, (width, height))
                
                # 混合两张图片
                alpha = j / transition_frames
                blended = cv2.addWeighted(rotated_current, 1 - alpha, rotated_next, alpha, 0)
                video_writer.write(blended)
        
        elif transition_style == "checkerboard":
            # 棋盘格过渡效果
            for j in range(transition_frames):
                # 创建棋盘格掩码
                board_size = 60  # 棋盘格大小
                mask = np.zeros((height, width), dtype=np.uint8)
                
                # 填充棋盘格
                for y in range(0, height, board_size):
                    for x in range(0, width, board_size):
                        if (y // board_size + x // board_size) % 2 == 0:
                            if j / transition_frames > np.random.rand():
                                mask[y:y+board_size, x:x+board_size] = 255
                
                # 应用掩码
                transition_frame = np.where(mask[:, :, np.newaxis] == 255, next_image, current_image)
                video_writer.write(transition_frame)
        
        elif transition_style == "door":
            # 门过渡效果
            for j in range(transition_frames):
                # 创建门状掩码
                door_width = int(width * 0.5)  # 门的宽度
                shift = int(door_width * (j / transition_frames))
                
                mask = np.ones((height, width), dtype=np.uint8) * 255
                
                # 左门
                mask[:, :shift] = 0
                # 右门
                mask[:, width - shift:] = 0
                
                # 应用掩码
                transition_frame = np.where(mask[:, :, np.newaxis] == 255, next_image, current_image)
                video_writer.write(transition_frame)
        
        elif transition_style == "horizontal_blinds":
            # 水平百叶窗效果
            for j in range(transition_frames):
                blind_height = 20  # 百叶窗高度
                transition_frame = np.copy(current_image)
                
                for y in range(0, height, blind_height):
                    if j / transition_frames > np.random.rand():
                        # 替换为下一张图片的对应区域
                        transition_frame[y:y+blind_height, :] = next_image[y:y+blind_height, :]
                
                video_writer.write(transition_frame)
        
        elif transition_style == "vertical_blinds":
            # 垂直百叶窗效果
            for j in range(transition_frames):
                blind_width = 20  # 百叶窗宽度
                transition_frame = np.copy(current_image)
                
                for x in range(0, width, blind_width):
                    if j / transition_frames > np.random.rand():
                        # 替换为下一张图片的对应区域
                        transition_frame[:, x:x+blind_width] = next_image[:, x:x+blind_width]
                
                video_writer.write(transition_frame)
        
        elif transition_style == "dissolve":
            # 溶解效果
            for j in range(transition_frames):
                # 创建随机溶解掩码
                mask = np.random.rand(height, width) < (j / transition_frames)
                mask = mask.astype(np.uint8) * 255
                
                # 应用掩码
                transition_frame = np.where(mask[:, :, np.newaxis] == 255, next_image, current_image)
                video_writer.write(transition_frame)
        
        elif transition_style == "flip":
            # 翻转效果
            for j in range(transition_frames):
                # 水平翻转当前图片
                flip_ratio = j / transition_frames
                flipped = cv2.flip(current_image, 1)
                
                # 创建过渡帧
                transition_frame = cv2.addWeighted(current_image, 1 - flip_ratio, flipped, flip_ratio, 0)
                video_writer.write(transition_frame)
        
        elif transition_style == "roll":
            # 滚动效果
            for j in range(transition_frames):
                # 滚动图片
                roll_amount = int(height * (j / transition_frames))
                transition_frame = np.roll(current_image, roll_amount, axis=0)
                
                # 确保滚动后的图片形状与原始图片一致
                if transition_frame.shape == current_image.shape:
                    # 混合两张图片
                    alpha = j / transition_frames
                    blended = cv2.addWeighted(transition_frame, 1 - alpha, next_image, alpha, 0)
                    video_writer.write(blended)
        
        elif transition_style == "grid_wipe":
            # 网格擦除效果
            for j in range(transition_frames):
                # 创建网格擦除掩码
                grid_size = 20
                mask = np.zeros((height, width), dtype=np.uint8)
                
                for y in range(0, height, grid_size):
                    for x in range(0, width, grid_size):
                        if j / transition_frames > np.random.rand():
                            mask[y:y+grid_size, x:x+grid_size] = 255
                
                # 应用掩码
                transition_frame = np.where(mask[:, :, np.newaxis] == 255, next_image, current_image)
                video_writer.write(transition_frame)
        
        elif transition_style == "chaos":
            # 混沌效果
            for j in range(transition_frames):
                # 创建随机混沌掩码
                mask = np.random.rand(height, width) < (j / transition_frames)
                mask = mask.astype(np.uint8) * 255
                
                # 应用掩码
                transition_frame = np.where(mask[:, :, np.newaxis] == 255, next_image, current_image)
                video_writer.write(transition_frame)
    
    # 处理最后一张图片
    last_image = processed_images[-1]
    for _ in range(display_frames):
        video_writer.write(last_image)
    
    video_writer.release()
    print(f"视频已成功创建: {output_video_path}")

# 示例使用
if __name__ == "__main__":
    # 设置图片目录和输出路径
    image_directory = "images"  # 替换为你的图片目录

    # 使用当前时间生成输出视频文件名
    current_time = datetime.now().strftime("%Y%m%d_%H%M%S")
    output_video_path = f"{current_time}_output_video.mp4"

    # 获取目录下所有文件路径
    all_files = list(Path(image_directory).iterdir())

    # 过滤出常见图片格式的文件
    image_extensions = ['.jpg', '.jpeg', '.png', '.gif', '.bmp', '.webp']
    image_files = [file for file in all_files if file.suffix.lower() in image_extensions]

    # 对图片文件进行重命名
    for index, image_file in enumerate(image_files):
        # 获取文件的扩展名
        file_extension = image_file.suffix
        # 构造新的文件路径
        new_path = Path(image_directory) / f"{index}{file_extension}"
        # 重命名文件
        image_file.rename(new_path)
        print(f"Renamed: {image_file.name} -> {index}{file_extension}")

    # 获取所有图片文件路径并排序
    image_paths = []
    for ext in image_extensions:
        image_paths.extend(Path(image_directory).glob('*' + ext))
    image_paths = list(map(str, image_paths))
    image_paths.sort()  # 按名称排序

    print("Sorted image paths:")
    for path in image_paths:
        print(path)
    
    if not image_paths:
        print("图片目录中没有找到图片文件！")
    else:
        # 创建视频
        create_video_from_images(
            image_paths, 
            output_video_path, 
            fps=60, 
            transition_duration=1
        )
# Out:
# Renamed: 0.png -> 0.png
# Renamed: 1.png -> 1.png
# Renamed: 2.png -> 2.png
# Renamed: 3.png -> 3.png
# Sorted image paths:
# images\0.png
# images\1.png
# images\2.png
# images\3.png
# 视频已成功创建: 20250711_154128_output_video.mp4
